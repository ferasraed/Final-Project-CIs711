# %% [markdown]
# # **FriedmanTest**

# %% [markdown]
# # **Dim 100**

# %% [markdown]
# # Dim 100_01

# %%
import pandas as pd
from scipy.stats import friedmanchisquare

file_path = 'Dim 100_1.csv'
data = pd.read_csv(file_path)

data_papers = data.iloc[:, 1:]

statistic, p_value = friedmanchisquare(*[data_papers[paper] for paper in data_papers.columns])

print(f"Friedman test statistic: {statistic}")
print(f"p-value: {p_value}")

ranks = data_papers.rank(axis=1)

average_ranks = ranks.mean()

average_ranks_sorted = average_ranks.sort_values(ascending=False)
print("\nAverage ranks for each paper:")
print(average_ranks_sorted)
# Out:
# Friedman test statistic: 169.33333333333326
# p-value: 3.811804476512449e-31
#
# Average ranks for each paper:
# p11    9.333333
# p5     8.833333
# p7     8.066667
# p2     7.833333
# p8     6.933333
# p1     6.866667
# p12    4.833333
# p3     4.566667
# p9     3.733333
# p4     3.066667
# p10    1.933333
# dtype: float64

# %% [markdown]
# ## Friedman average ranking results

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('Dim 100_1.csv')

data_papers = data.iloc[:, 1:]  # Assuming data is already loaded and prepared
ranks = data_papers.rank(axis=1)
average_ranks = ranks.mean()
average_ranks_sorted = average_ranks.sort_values(ascending=False)

colors = ['#4D79DA', '#EF8133', '#B8B8B8', '#FFCF00', '#77ADD4', '#52B242', '#1D348A', '#9B3F00', '#716C6B', '#A37503', '#1A3B6F']

plt.figure(figsize=(10, 6))  # Set the figure size

average_ranks_sorted.plot(kind='bar', color=colors[:len(average_ranks_sorted)])
plt.title('Average Ranks of Papers - Friedman Test Results')
plt.xlabel('Papers')
plt.ylabel('Average Rank')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# # Dim 100_02

# %%
import pandas as pd
from scipy.stats import friedmanchisquare

file_path = 'Dim 100_2.csv'
data = pd.read_csv(file_path)

data_papers = data.iloc[:, 1:]

statistic, p_value = friedmanchisquare(*[data_papers[paper] for paper in data_papers.columns])

print(f"Friedman test statistic: {statistic}")
print(f"p-value: {p_value}")

ranks = data_papers.rank(axis=1)

average_ranks = ranks.mean()

average_ranks_sorted = average_ranks.sort_values(ascending=False)
print("\nAverage ranks for each paper:")
print(average_ranks_sorted)
# Out:
# Friedman test statistic: 181.79999999999995
# p-value: 9.908213413419402e-34
#
# Average ranks for each paper:
# p7     9.266667
# p8     9.100000
# p5     8.733333
# p11    8.066667
# p1     6.466667
# p2     6.300000
# p12    4.900000
# p3     4.633333
# p9     3.800000
# p4     2.433333
# p10    2.300000
# dtype: float64

# %% [markdown]
# ## Friedman average ranking results

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('Dim 100_2.csv')

data_papers = data.iloc[:, 1:]  # Assuming data is already loaded and prepared
ranks = data_papers.rank(axis=1)
average_ranks = ranks.mean()
average_ranks_sorted = average_ranks.sort_values(ascending=False)

colors = ['#4D79DA', '#EF8133', '#B8B8B8', '#FFCF00', '#77ADD4', '#52B242', '#1D348A', '#9B3F00', '#716C6B', '#A37503', '#1A3B6F']

plt.figure(figsize=(10, 6))  # Set the figure size

average_ranks_sorted.plot(kind='bar', color=colors[:len(average_ranks_sorted)])
plt.title('Average Ranks of Papers - Friedman Test Results')
plt.xlabel('Papers')
plt.ylabel('Average Rank')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# # Dim 100_03

# %%
import pandas as pd
from scipy.stats import friedmanchisquare

file_path = 'Dim 100_3.csv'
data = pd.read_csv(file_path)

data_papers = data.iloc[:, 1:]

statistic, p_value = friedmanchisquare(*[data_papers[paper] for paper in data_papers.columns])

print(f"Friedman test statistic: {statistic}")
print(f"p-value: {p_value}")

ranks = data_papers.rank(axis=1)

average_ranks = ranks.mean()

average_ranks_sorted = average_ranks.sort_values(ascending=False)
print("\nAverage ranks for each paper:")
print(average_ranks_sorted)
# Out:
# Friedman test statistic: 192.5818181818181
# p-value: 5.6721322172269624e-36
#
# Average ranks for each paper:
# p7     9.633333
# p8     9.366667
# p5     8.733333
# p11    7.966667
# p1     6.366667
# p2     5.966667
# p12    4.966667
# p3     4.300000
# p9     4.000000
# p4     2.366667
# p10    2.333333
# dtype: float64

# %% [markdown]
# ## Friedman average ranking results

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('Dim 100_3.csv')

data_papers = data.iloc[:, 1:]  # Assuming data is already loaded and prepared
ranks = data_papers.rank(axis=1)
average_ranks = ranks.mean()
average_ranks_sorted = average_ranks.sort_values(ascending=False)

colors = ['#4D79DA', '#EF8133', '#B8B8B8', '#FFCF00', '#77ADD4', '#52B242', '#1D348A', '#9B3F00', '#716C6B', '#A37503', '#1A3B6F']

plt.figure(figsize=(10, 6))  # Set the figure size

average_ranks_sorted.plot(kind='bar', color=colors[:len(average_ranks_sorted)])
plt.title('Average Ranks of Papers - Friedman Test Results')
plt.xlabel('Papers')
plt.ylabel('Average Rank')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# # Dim 100_04

# %%
import pandas as pd
from scipy.stats import friedmanchisquare

file_path = 'Dim 100_4.csv'
data = pd.read_csv(file_path)

data_papers = data.iloc[:, 1:]

statistic, p_value = friedmanchisquare(*[data_papers[paper] for paper in data_papers.columns])

print(f"Friedman test statistic: {statistic}")
print(f"p-value: {p_value}")

ranks = data_papers.rank(axis=1)

average_ranks = ranks.mean()

average_ranks_sorted = average_ranks.sort_values(ascending=False)
print("\nAverage ranks for each paper:")
print(average_ranks_sorted)
# Out:
# Friedman test statistic: 184.3939393939395
# p-value: 2.864606554758836e-34
#
# Average ranks for each paper:
# p8     9.633333
# p7     9.466667
# p5     8.366667
# p11    7.766667
# p1     6.733333
# p2     5.500000
# p12    5.333333
# p9     4.333333
# p3     4.066667
# p10    2.433333
# p4     2.366667
# dtype: float64

# %% [markdown]
# ## Friedman average ranking results

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('Dim 100_4.csv')

data_papers = data.iloc[:, 1:]  # Assuming data is already loaded and prepared
ranks = data_papers.rank(axis=1)
average_ranks = ranks.mean()
average_ranks_sorted = average_ranks.sort_values(ascending=False)

colors = ['#4D79DA', '#EF8133', '#B8B8B8', '#FFCF00', '#77ADD4', '#52B242', '#1D348A', '#9B3F00', '#716C6B', '#A37503', '#1A3B6F']

plt.figure(figsize=(10, 6))  # Set the figure size

average_ranks_sorted.plot(kind='bar', color=colors[:len(average_ranks_sorted)])
plt.title('Average Ranks of Papers - Friedman Test Results')
plt.xlabel('Papers')
plt.ylabel('Average Rank')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# # Dim 100_05

# %%
import pandas as pd
from scipy.stats import friedmanchisquare

file_path = 'Dim 100_5.csv'
data = pd.read_csv(file_path)

data_papers = data.iloc[:, 1:]

statistic, p_value = friedmanchisquare(*[data_papers[paper] for paper in data_papers.columns])

print(f"Friedman test statistic: {statistic}")
print(f"p-value: {p_value}")

ranks = data_papers.rank(axis=1)

average_ranks = ranks.mean()

average_ranks_sorted = average_ranks.sort_values(ascending=False)
print("\nAverage ranks for each paper:")
print(average_ranks_sorted)
# Out:
# Friedman test statistic: 145.37575757575746
# p-value: 3.32595793481232e-26
#
# Average ranks for each paper:
# p8     9.966667
# p7     8.166667
# p5     7.733333
# p11    7.333333
# p1     7.066667
# p12    5.900000
# p9     5.500000
# p2     4.766667
# p3     4.100000
# p10    3.066667
# p4     2.400000
# dtype: float64

# %% [markdown]
# ## Friedman average ranking results

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('Dim 100_5.csv')

data_papers = data.iloc[:, 1:]  # Assuming data is already loaded and prepared
ranks = data_papers.rank(axis=1)
average_ranks = ranks.mean()
average_ranks_sorted = average_ranks.sort_values(ascending=False)

colors = ['#4D79DA', '#EF8133', '#B8B8B8', '#FFCF00', '#77ADD4', '#52B242', '#1D348A', '#9B3F00', '#716C6B', '#A37503', '#1A3B6F']

plt.figure(figsize=(10, 6))  # Set the figure size

average_ranks_sorted.plot(kind='bar', color=colors[:len(average_ranks_sorted)])
plt.title('Average Ranks of Papers - Friedman Test Results')
plt.xlabel('Papers')
plt.ylabel('Average Rank')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# # Dim 100_06

# %%
import pandas as pd
from scipy.stats import friedmanchisquare

file_path = 'Dim 100_6.csv'
data = pd.read_csv(file_path)

data_papers = data.iloc[:, 1:]

statistic, p_value = friedmanchisquare(*[data_papers[paper] for paper in data_papers.columns])

print(f"Friedman test statistic: {statistic}")
print(f"p-value: {p_value}")

ranks = data_papers.rank(axis=1)

average_ranks = ranks.mean()

average_ranks_sorted = average_ranks.sort_values(ascending=False)
print("\nAverage ranks for each paper:")
print(average_ranks_sorted)
# Out:
# Friedman test statistic: 93.23636363636365
# p-value: 1.2191057820156674e-15
#
# Average ranks for each paper:
# p8     9.366667
# p5     7.266667
# p11    6.933333
# p9     6.866667
# p12    6.733333
# p1     6.600000
# p7     6.533333
# p3     4.433333
# p2     4.333333
# p10    3.900000
# p4     3.033333
# dtype: float64

# %% [markdown]
# ## Friedman average ranking results

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('Dim 100_6.csv')

data_papers = data.iloc[:, 1:]  # Assuming data is already loaded and prepared
ranks = data_papers.rank(axis=1)
average_ranks = ranks.mean()
average_ranks_sorted = average_ranks.sort_values(ascending=False)

colors = ['#4D79DA', '#EF8133', '#B8B8B8', '#FFCF00', '#77ADD4', '#52B242', '#1D348A', '#9B3F00', '#716C6B', '#A37503', '#1A3B6F']

plt.figure(figsize=(10, 6))  # Set the figure size

average_ranks_sorted.plot(kind='bar', color=colors[:len(average_ranks_sorted)])
plt.title('Average Ranks of Papers - Friedman Test Results')
plt.xlabel('Papers')
plt.ylabel('Average Rank')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# # Dim 100_07

# %%
import pandas as pd
from scipy.stats import friedmanchisquare

file_path = 'Dim 100_7.csv'
data = pd.read_csv(file_path)

data_papers = data.iloc[:, 1:]

statistic, p_value = friedmanchisquare(*[data_papers[paper] for paper in data_papers.columns])

print(f"Friedman test statistic: {statistic}")
print(f"p-value: {p_value}")

ranks = data_papers.rank(axis=1)

average_ranks = ranks.mean()

average_ranks_sorted = average_ranks.sort_values(ascending=False)
print("\nAverage ranks for each paper:")
print(average_ranks_sorted)
# Out:
# Friedman test statistic: 52.82424242424236
# p-value: 8.026921260186326e-08
#
# Average ranks for each paper:
# p9     7.733333
# p8     7.666667
# p12    7.400000
# p11    7.033333
# p5     6.166667
# p1     6.033333
# p7     5.800000
# p10    5.066667
# p3     4.966667
# p2     4.800000
# p4     3.333333
# dtype: float64

# %% [markdown]
# ## Friedman average ranking results

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('Dim 100_7.csv')

data_papers = data.iloc[:, 1:]  # Assuming data is already loaded and prepared
ranks = data_papers.rank(axis=1)
average_ranks = ranks.mean()
average_ranks_sorted = average_ranks.sort_values(ascending=False)

colors = ['#4D79DA', '#EF8133', '#B8B8B8', '#FFCF00', '#77ADD4', '#52B242', '#1D348A', '#9B3F00', '#716C6B', '#A37503', '#1A3B6F']

plt.figure(figsize=(10, 6))  # Set the figure size

average_ranks_sorted.plot(kind='bar', color=colors[:len(average_ranks_sorted)])
plt.title('Average Ranks of Papers - Friedman Test Results')
plt.xlabel('Papers')
plt.ylabel('Average Rank')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# # Dim 100_08

# %%
import pandas as pd
from scipy.stats import friedmanchisquare

file_path = 'Dim 100_8.csv'
data = pd.read_csv(file_path)

data_papers = data.iloc[:, 1:]

statistic, p_value = friedmanchisquare(*[data_papers[paper] for paper in data_papers.columns])

print(f"Friedman test statistic: {statistic}")
print(f"p-value: {p_value}")

ranks = data_papers.rank(axis=1)

average_ranks = ranks.mean()

average_ranks_sorted = average_ranks.sort_values(ascending=False)
print("\nAverage ranks for each paper:")
print(average_ranks_sorted)
# Out:
# Friedman test statistic: 69.73333333333335
# p-value: 4.991718369694299e-11
#
# Average ranks for each paper:
# p9     8.533333
# p12    7.966667
# p8     7.466667
# p11    6.833333
# p10    6.400000
# p1     5.766667
# p3     5.466667
# p7     4.933333
# p5     4.800000
# p2     4.500000
# p4     3.333333
# dtype: float64

# %% [markdown]
# ## Friedman average ranking results

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('Dim 100_8.csv')

data_papers = data.iloc[:, 1:]  # Assuming data is already loaded and prepared
ranks = data_papers.rank(axis=1)
average_ranks = ranks.mean()
average_ranks_sorted = average_ranks.sort_values(ascending=False)

colors = ['#4D79DA', '#EF8133', '#B8B8B8', '#FFCF00', '#77ADD4', '#52B242', '#1D348A', '#9B3F00', '#716C6B', '#A37503', '#1A3B6F']

plt.figure(figsize=(10, 6))  # Set the figure size

average_ranks_sorted.plot(kind='bar', color=colors[:len(average_ranks_sorted)])
plt.title('Average Ranks of Papers - Friedman Test Results')
plt.xlabel('Papers')
plt.ylabel('Average Rank')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# # Dim 100_09

# %%
import pandas as pd
from scipy.stats import friedmanchisquare

file_path = 'Dim 100_9.csv'
data = pd.read_csv(file_path)

data_papers = data.iloc[:, 1:]

statistic, p_value = friedmanchisquare(*[data_papers[paper] for paper in data_papers.columns])

print(f"Friedman test statistic: {statistic}")
print(f"p-value: {p_value}")

ranks = data_papers.rank(axis=1)

average_ranks = ranks.mean()

average_ranks_sorted = average_ranks.sort_values(ascending=False)
print("\nAverage ranks for each paper:")
print(average_ranks_sorted)
# Out:
# Friedman test statistic: 107.4545454545455
# p-value: 1.7379474676297727e-18
#
# Average ranks for each paper:
# p9     9.266667
# p12    8.466667
# p8     7.766667
# p10    7.100000
# p11    6.133333
# p1     6.066667
# p3     5.466667
# p2     4.733333
# p7     3.866667
# p4     3.633333
# p5     3.500000
# dtype: float64

# %% [markdown]
# ## Friedman average ranking results

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('Dim 100_9.csv')

data_papers = data.iloc[:, 1:]  # Assuming data is already loaded and prepared
ranks = data_papers.rank(axis=1)
average_ranks = ranks.mean()
average_ranks_sorted = average_ranks.sort_values(ascending=False)

colors = ['#4D79DA', '#EF8133', '#B8B8B8', '#FFCF00', '#77ADD4', '#52B242', '#1D348A', '#9B3F00', '#716C6B', '#A37503', '#1A3B6F']

plt.figure(figsize=(10, 6))  # Set the figure size

average_ranks_sorted.plot(kind='bar', color=colors[:len(average_ranks_sorted)])
plt.title('Average Ranks of Papers - Friedman Test Results')
plt.xlabel('Papers')
plt.ylabel('Average Rank')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# # Dim 100_10

# %%
import pandas as pd
from scipy.stats import friedmanchisquare

file_path = 'Dim 100_10.csv'
data = pd.read_csv(file_path)

data_papers = data.iloc[:, 1:]

statistic, p_value = friedmanchisquare(*[data_papers[paper] for paper in data_papers.columns])

print(f"Friedman test statistic: {statistic}")
print(f"p-value: {p_value}")

ranks = data_papers.rank(axis=1)

average_ranks = ranks.mean()

average_ranks_sorted = average_ranks.sort_values(ascending=False)
print("\nAverage ranks for each paper:")
print(average_ranks_sorted)
# Out:
# Friedman test statistic: 136.86770722836783
# p-value: 1.845778278849955e-24
#
# Average ranks for each paper:
# p9     9.466667
# p12    8.666667
# p8     8.200000
# p10    7.633333
# p11    6.033333
# p1     5.933333
# p3     5.633333
# p4     4.116667
# p2     3.700000
# p7     3.500000
# p5     3.116667
# dtype: float64

# %% [markdown]
# ## Friedman average ranking results

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('Dim 100_10.csv')

data_papers = data.iloc[:, 1:]  # Assuming data is already loaded and prepared
ranks = data_papers.rank(axis=1)
average_ranks = ranks.mean()
average_ranks_sorted = average_ranks.sort_values(ascending=False)

colors = ['#4D79DA', '#EF8133', '#B8B8B8', '#FFCF00', '#77ADD4', '#52B242', '#1D348A', '#9B3F00', '#716C6B', '#A37503', '#1A3B6F']

plt.figure(figsize=(10, 6))  # Set the figure size

average_ranks_sorted.plot(kind='bar', color=colors[:len(average_ranks_sorted)])
plt.title('Average Ranks of Papers - Friedman Test Results')
plt.xlabel('Papers')
plt.ylabel('Average Rank')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# # Dim 100_11

# %%
import pandas as pd
from scipy.stats import friedmanchisquare

file_path = 'Dim 100_11.csv'
data = pd.read_csv(file_path)

data_papers = data.iloc[:, 1:]

statistic, p_value = friedmanchisquare(*[data_papers[paper] for paper in data_papers.columns])

print(f"Friedman test statistic: {statistic}")
print(f"p-value: {p_value}")

ranks = data_papers.rank(axis=1)

average_ranks = ranks.mean()

average_ranks_sorted = average_ranks.sort_values(ascending=False)
print("\nAverage ranks for each paper:")
print(average_ranks_sorted)
# Out:
# Friedman test statistic: 147.31130645650194
# p-value: 1.3312865536241862e-26
#
# Average ranks for each paper:
# p9     9.533333
# p12    8.766667
# p8     8.366667
# p10    7.833333
# p3     5.800000
# p11    5.766667
# p1     5.666667
# p4     4.200000
# p2     3.866667
# p5     3.300000
# p7     2.900000
# dtype: float64

# %% [markdown]
# ## Friedman average ranking results

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('Dim 100_11.csv')

data_papers = data.iloc[:, 1:]  # Assuming data is already loaded and prepared
ranks = data_papers.rank(axis=1)
average_ranks = ranks.mean()
average_ranks_sorted = average_ranks.sort_values(ascending=False)

colors = ['#4D79DA', '#EF8133', '#B8B8B8', '#FFCF00', '#77ADD4', '#52B242', '#1D348A', '#9B3F00', '#716C6B', '#A37503', '#1A3B6F']

plt.figure(figsize=(10, 6))  # Set the figure size

average_ranks_sorted.plot(kind='bar', color=colors[:len(average_ranks_sorted)])
plt.title('Average Ranks of Papers - Friedman Test Results')
plt.xlabel('Papers')
plt.ylabel('Average Rank')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# # Dim 100_12

# %%
import pandas as pd
from scipy.stats import friedmanchisquare

file_path = 'Dim 100_12.csv'
data = pd.read_csv(file_path)

data_papers = data.iloc[:, 1:]

statistic, p_value = friedmanchisquare(*[data_papers[paper] for paper in data_papers.columns])

print(f"Friedman test statistic: {statistic}")
print(f"p-value: {p_value}")

ranks = data_papers.rank(axis=1)

average_ranks = ranks.mean()

average_ranks_sorted = average_ranks.sort_values(ascending=False)
print("\nAverage ranks for each paper:")
print(average_ranks_sorted)
# Out:
# Friedman test statistic: 160.36374658987566
# p-value: 2.7257228331437233e-29
#
# Average ranks for each paper:
# p9     9.700000
# p12    8.900000
# p8     8.766667
# p10    7.966667
# p3     5.800000
# p1     5.566667
# p4     4.533333
# p2     4.366667
# p11    4.166667
# p5     3.366667
# p7     2.866667
# dtype: float64

# %% [markdown]
# ## Friedman average ranking results

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('Dim 100_12.csv')

data_papers = data.iloc[:, 1:]  # Assuming data is already loaded and prepared
ranks = data_papers.rank(axis=1)
average_ranks = ranks.mean()
average_ranks_sorted = average_ranks.sort_values(ascending=False)

colors = ['#4D79DA', '#EF8133', '#B8B8B8', '#FFCF00', '#77ADD4', '#52B242', '#1D348A', '#9B3F00', '#716C6B', '#A37503', '#1A3B6F']

plt.figure(figsize=(10, 6))  # Set the figure size

average_ranks_sorted.plot(kind='bar', color=colors[:len(average_ranks_sorted)])
plt.title('Average Ranks of Papers - Friedman Test Results')
plt.xlabel('Papers')
plt.ylabel('Average Rank')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# # Dim 100_13

# %%
import pandas as pd
from scipy.stats import friedmanchisquare

file_path = 'Dim 100_13.csv'
data = pd.read_csv(file_path)

data_papers = data.iloc[:, 1:]

statistic, p_value = friedmanchisquare(*[data_papers[paper] for paper in data_papers.columns])

print(f"Friedman test statistic: {statistic}")
print(f"p-value: {p_value}")

ranks = data_papers.rank(axis=1)

average_ranks = ranks.mean()

average_ranks_sorted = average_ranks.sort_values(ascending=False)
print("\nAverage ranks for each paper:")
print(average_ranks_sorted)
# Out:
# Friedman test statistic: 164.75519175382757
# p-value: 3.3746726401534706e-30
#
# Average ranks for each paper:
# p9     9.733333
# p12    8.966667
# p8     8.766667
# p10    8.033333
# p3     5.900000
# p1     5.300000
# p2     4.516667
# p4     4.466667
# p11    4.200000
# p5     3.416667
# p7     2.700000
# dtype: float64

# %% [markdown]
# ## Friedman average ranking results

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('Dim 100_13.csv')

data_papers = data.iloc[:, 1:]  # Assuming data is already loaded and prepared
ranks = data_papers.rank(axis=1)
average_ranks = ranks.mean()
average_ranks_sorted = average_ranks.sort_values(ascending=False)

colors = ['#4D79DA', '#EF8133', '#B8B8B8', '#FFCF00', '#77ADD4', '#52B242', '#1D348A', '#9B3F00', '#716C6B', '#A37503', '#1A3B6F']

plt.figure(figsize=(10, 6))  # Set the figure size

average_ranks_sorted.plot(kind='bar', color=colors[:len(average_ranks_sorted)])
plt.title('Average Ranks of Papers - Friedman Test Results')
plt.xlabel('Papers')
plt.ylabel('Average Rank')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# # Dim 100_14

# %%
import pandas as pd
from scipy.stats import friedmanchisquare

file_path = 'Dim 100_14.csv'
data = pd.read_csv(file_path)

data_papers = data.iloc[:, 1:]

statistic, p_value = friedmanchisquare(*[data_papers[paper] for paper in data_papers.columns])

print(f"Friedman test statistic: {statistic}")
print(f"p-value: {p_value}")

ranks = data_papers.rank(axis=1)

average_ranks = ranks.mean()

average_ranks_sorted = average_ranks.sort_values(ascending=False)
print("\nAverage ranks for each paper:")
print(average_ranks_sorted)
# Out:
# Friedman test statistic: 173.87321807703975
# p-value: 4.372401651215744e-32
#
# Average ranks for each paper:
# p9     9.800000
# p8     9.000000
# p12    9.000000
# p10    8.133333
# p3     5.966667
# p2     4.733333
# p4     4.733333
# p1     4.366667
# p11    4.066667
# p5     3.466667
# p7     2.733333
# dtype: float64

# %% [markdown]
# ## Friedman average ranking results

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('Dim 100_14.csv')

data_papers = data.iloc[:, 1:]  # Assuming data is already loaded and prepared
ranks = data_papers.rank(axis=1)
average_ranks = ranks.mean()
average_ranks_sorted = average_ranks.sort_values(ascending=False)

colors = ['#4D79DA', '#EF8133', '#B8B8B8', '#FFCF00', '#77ADD4', '#52B242', '#1D348A', '#9B3F00', '#716C6B', '#A37503', '#1A3B6F']

plt.figure(figsize=(10, 6))  # Set the figure size

average_ranks_sorted.plot(kind='bar', color=colors[:len(average_ranks_sorted)])
plt.title('Average Ranks of Papers - Friedman Test Results')
plt.xlabel('Papers')
plt.ylabel('Average Rank')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Wilcoxon Signed-Rank Test**

# %% [markdown]
# ## Results according on a control method p10

# %% [markdown]
# # **Dim 100**

# %% [markdown]
# # Dim 100_01

# %%
import pandas as pd
from scipy.stats import wilcoxon

means = pd.read_csv('Dim 100_1.csv', index_col=0)
stds = pd.read_csv('Dim 100_std_1.csv', index_col=0)

functions = means.index.tolist()
papers = means.columns.tolist()

reference_paper = 'p10'

if reference_paper not in papers:
    papers.append(reference_paper)

formatted_results = pd.DataFrame(index=functions, columns=pd.MultiIndex.from_product([papers, ['F', 'STD', '+/-/=']]))

for function in functions:
    formatted_results.loc[function, (reference_paper, 'F')] = means.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, 'STD')] = stds.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, '+/-/=')] = '='  # Indicate no comparison

for paper in papers:
    if paper == reference_paper:
        continue  # Skip comparison logic for p10
    for function in functions:
        data_ref = means.loc[function, reference_paper]
        data_comp = means.loc[function, paper]
        std_ref = stds.loc[function, reference_paper]
        std_comp = stds.loc[function, paper]

        try:
            stat, p_value = wilcoxon(means.loc[:, reference_paper].dropna(), means.loc[:, paper].dropna(), alternative='two-sided')
            if p_value <= 0.05:
                symbol = '-' if data_ref > data_comp else '+'
            else:
                symbol = '='
        except Exception as e:
            symbol = 'Err'
            print(f"Error: {e}")

        formatted_results.loc[function, (paper, 'F')] = data_comp
        formatted_results.loc[function, (paper, 'STD')] = std_comp
        formatted_results.loc[function, (paper, '+/-/=')] = symbol

formatted_results.to_csv('formatted_wilcoxon_results_control_p10_1.csv')
print(formatted_results.head())
# Out:
#                                                    p1                      \
#                                                     F                 STD
# f1                                261501666666.666626  13593605184.368742
# f2  2061650231591019688793294489410570918320759770...                 inf
# f3                                      627329.078431        50107.210092
# f4                                       69425.766667         6518.123189
# f5                                         1663.69902           37.913748
#
#                                                          p2  \
#    +/-/=                                                  F
# f1     +                                259349002745.098053
# f2     +  4975508439539579430767503775482461352302970886...
# f3     +                                      671941.591961
# f4     +                                       70103.339294
# f5     +                                         1644.59988
#
#                                               p3                          \
#                    STD +/-/=                   F               STD +/-/=
# f1  21834635591.669582     +  30155384313.725491  3039489364.96806     =
# f2                 inf     +        27598.378431        880.975915     =
# f3        99304.408387     +       193248.509804      22826.299123     =
# f4        11749.908808     +   4574092549.019608  547386464.821677     =
# f5           52.538914     +    126270739.215686   26313335.149901     =
#
#                                                    p4  ...    p9  \
#                                                     F  ... +/-/=
# f1                                  1697076735.163364  ...     +
# f2  1300552008392559773513602330073840423260377329...  ...     +
# f3                                      850213.089013  ...     -
# f4                                         836.011953  ...     +
# f5                                          951.40266  ...     +
#
#                                                   p10  \
#                                                     F
# f1                                     7376274.509804
# f2  1306680750133168979546908247502634329102032736...
# f3                                      603725.490196
# f4                                         476.784314
# f5                                         796.568627
#
#                                                              \
#                                                   STD +/-/=
# f1                                      3680417.15495     =
# f2  9177461239060090639231093728918972090766387187...     =
# f3                                        69810.40948     =
# f4                                          60.072281     =
# f5                                          78.513707     =
#
#                                                   p11                      \
#                                                     F                 STD
# f1                                317276714901.960754  13692902182.430332
# f2  2217362724445256244789285307434201486456200254...                 inf
# f3                                      671755.189608        72110.399455
# f4                                       94171.643667         10317.91962
# f5                                        1822.436314           50.250565
#
#                                                         p12  \
#    +/-/=                                                  F
# f1     +                                146595609627.450989
# f2     +  9625983830320396642069940174151119966349685258...
# f3     +                                      380264.546784
# f4     +                                       31285.842243
# f5     +                                        1252.897997
#
#
#                                                   STD +/-/=
# f1                                 11361827304.209375     +
# f2  2686675768866349716166325017296178254316241430...     +
# f3                                       27828.235376     -
# f4                                        4058.344278     +
# f5                                          41.101442     +
#
# [5 rows x 33 columns]

# %%
wilcoxon_results = pd.read_csv('formatted_wilcoxon_results_control_p10_1.csv')

wilcoxon_results.head(10)
# Out:
#   Unnamed: 0                       p1                p1.1   p1.2  \
# 0        NaN                        F                 STD  +/-/=
# 1         f1       261501666666.66663  13593605184.368742      +
# 2         f2  2.0616502315910197e+165                 inf      +
# 3         f3        627329.0784313725   50107.21009166564      +
# 4         f4        69425.76666666666   6518.123188514743      +
# 5         f5       1663.6990196078434   37.91374784309011      +
# 6         f6       113.15960784313728    3.28011950450895      +
# 7         f7         5355.31705882353   282.7396938451749      +
# 8         f8       1719.5472549019603   53.28771550589297      +
# 9         f9        106377.1588235294  6587.8072613143495      +
#
#                        p2                p2.1   p2.2                  p3  \
# 0                       F                 STD  +/-/=                   F
# 1      259349002745.09805  21834635591.669582      +   30155384313.72549
# 2  4.975508439539579e+173                 inf      +   27598.37843137255
# 3       671941.5919607844      99304.40838722      +   193248.5098039216
# 4       70103.33929411764  11749.908808431435      +   4574092549.019608
# 5       1644.599880392157     52.538914330756      +  126270739.21568628
# 6       111.2664513137255   5.536951705684645      +  12005259.607843136
# 7       3632.102937254902   70.31171501821818      +  16277737.450980391
# 8      1727.2298843137255   83.52487725969084      +   8294.688823529412
# 9      100612.58043137255   8892.909674949844      +   5065.855490196077
#
#                  p3.1   p3.2  ...   p9.2                     p10  \
# 0                 STD  +/-/=  ...  +/-/=                       F
# 1    3039489364.96806      =  ...      +       7376274.509803922
# 2   880.9759154780802      =  ...      +  1.306680750133169e+115
# 3  22826.299123197092      =  ...      -       603725.4901960784
# 4   547386464.8216771      =  ...      +       476.7843137254902
# 5   26313335.14990092      =  ...      +       796.5686274509804
# 6   3206744.872407166      =  ...      +      27.121568627450976
# 7   4480519.049077729      =  ...      -      2047.2549019607843
# 8   379.7882862428005      =  ...      +       861.6274509803922
# 9  294.74558070038444      =  ...      +      23354.901960784315
#
#                    p10.1  p10.2                      p11               p11.1  \
# 0                    STD  +/-/=                        F                 STD
# 1     3680417.1549497335      =       317276714901.96075  13692902182.430332
# 2  9.17746123906009e+115      =  2.2173627244452562e+169                 inf
# 3      69810.40948038145      =        671755.1896078432   72110.39945538809
# 4      60.07228120878269      =        94171.64366666664   10317.91961976179
# 5      78.51370678434479      =       1822.4363137254904   50.25056467459149
# 6      4.473552508824708      =       120.02414980392156  3.7806707455244855
# 7      375.7871656250647      =        4208.138749019608   284.7272300873374
# 8      68.66627473264704      =       1903.9632098039212   58.99450403600508
# 9       2667.17988141034      =       108495.88823529411   12491.77518001936
#
#    p11.2                     p12                    p12.1  p12.2
# 0  +/-/=                       F                      STD  +/-/=
# 1      +        146595609627.451       11361827304.209375      +
# 2      +  9.625983830320397e+148  2.6866757688663497e+149      +
# 3      +      380264.54678431374        27828.23537560289      -
# 4      +      31285.842243137253        4058.344277780344      +
# 5      +      1252.8979968627452        41.10144153103345      +
# 6      +       86.31135137254904        4.247735748718946      +
# 7      +              2407.55536        148.1315508439177      +
# 8      +       1312.484685490196       48.121943266825234      +
# 9      +        57552.7717862745         4059.97689327274      +
#
# [10 rows x 34 columns]

# %% [markdown]
# ## Counting superior performances

# %%
data_wilcoxon = pd.read_csv('formatted_wilcoxon_results_control_p10_1.csv')
print(data_wilcoxon.head())

results = {}
comparison_columns = [col for col in data_wilcoxon.columns if col.endswith('.2')]

for col in comparison_columns:
    paper = col.split('.')[0]
    results[paper] = 0

for index, row in data_wilcoxon.iterrows():
    for col in comparison_columns:
        paper = col.split('.')[0]
        symbol = row[col]
        if symbol == '-':
            results[paper] += 1

print("Number of times each paper was better than the control (p10):")
for paper, count in results.items():
    print(f"{paper}: {count}")
# Out:
#   Unnamed: 0                       p1                p1.1   p1.2  \
# 0        NaN                        F                 STD  +/-/=
# 1         f1       261501666666.66663  13593605184.368742      +
# 2         f2  2.0616502315910197e+165                 inf      +
# 3         f3        627329.0784313725   50107.21009166564      +
# 4         f4        69425.76666666666   6518.123188514743      +
#
#                        p2                p2.1   p2.2                 p3  \
# 0                       F                 STD  +/-/=                  F
# 1      259349002745.09805  21834635591.669582      +  30155384313.72549
# 2  4.975508439539579e+173                 inf      +  27598.37843137255
# 3       671941.5919607844      99304.40838722      +  193248.5098039216
# 4       70103.33929411764  11749.908808431435      +  4574092549.019608
#
#                  p3.1   p3.2  ...   p9.2                     p10  \
# 0                 STD  +/-/=  ...  +/-/=                       F
# 1    3039489364.96806      =  ...      +       7376274.509803922
# 2   880.9759154780802      =  ...      +  1.306680750133169e+115
# 3  22826.299123197092      =  ...      -       603725.4901960784
# 4   547386464.8216771      =  ...      +       476.7843137254902
#
#                    p10.1  p10.2                      p11               p11.1  \
# 0                    STD  +/-/=                        F                 STD
# 1     3680417.1549497335      =       317276714901.96075  13692902182.430332
# 2  9.17746123906009e+115      =  2.2173627244452562e+169                 inf
# 3      69810.40948038145      =        671755.1896078432   72110.39945538809
# 4      60.07228120878269      =        94171.64366666664   10317.91961976179
#
#    p11.2                     p12                    p12.1  p12.2
# 0  +/-/=                       F                      STD  +/-/=
# 1      +        146595609627.451       11361827304.209375      +
# 2      +  9.625983830320397e+148  2.6866757688663497e+149      +
# 3      +      380264.54678431374        27828.23537560289      -
# 4      +      31285.842243137253        4058.344277780344      +
#
# [5 rows x 34 columns]
# Number of times each paper was better than the control (p10):
# p1: 0
# p2: 0
# p3: 0
# p4: 7
# p5: 1
# p7: 1
# p8: 0
# p9: 2
# p10: 0
# p11: 0
# p12: 1

# %% [markdown]
# ## Wilcoxon Summary

# %%
import pandas as pd
from scipy.stats import wilcoxon

data = pd.read_csv('Dim 100_1.csv')

control = 'p10'
algorithms = [col for col in data.columns[1:13] if col != control]

results_list = []

for alg in algorithms:
    data_control = data[control].dropna().astype(float)
    data_alg = data[alg].dropna().astype(float)
    
    if len(data_control) > 0 and len(data_alg) > 0:
        stat, p_value = wilcoxon(data_control, data_alg, alternative='two-sided')
        better_count = sum(data_alg > data_control)
        worse_count = sum(data_alg < data_control)
        equal_count = sum(data_alg == data_control)
        
        l_value = '+' if better_count > worse_count else '-' if worse_count > better_count else '='
        
        results_list.append({
            'Proposed algorithm': alg,
            'R+': better_count,
            'R-': worse_count,
            'R=': equal_count,
            'P-value': f"{p_value:.2E}" if p_value is not None else "N/A",
            'L-value': l_value
        })

results = pd.DataFrame(results_list)


results.to_csv('wilcoxon_summary_results_control_p10_1.csv', index=False)

results
# Out:
#   Proposed algorithm  R+  R-  R=   P-value L-value
# 0                 p1  30   0   0  1.86E-09       +
# 1                 p2  30   0   0  1.86E-09       +
# 2                 p3  14  16   0  5.84E-01       -
# 3                 p4  23   7   0  5.55E-04       +
# 4                 p5  29   1   0  3.79E-06       +
# 5                 p7  29   1   0  4.71E-07       +
# 6                 p8  30   0   0  1.86E-09       +
# 7                 p9  28   2   0  6.91E-07       +
# 8                p11  30   0   0  1.86E-09       +
# 9                p12  29   1   0  8.33E-07       +

# %% [markdown]
# # Dim 100_02

# %%
import pandas as pd
from scipy.stats import wilcoxon

means = pd.read_csv('Dim 100_2.csv', index_col=0)
stds = pd.read_csv('Dim 100_std_2.csv', index_col=0)

functions = means.index.tolist()
papers = means.columns.tolist()

reference_paper = 'p10'

if reference_paper not in papers:
    papers.append(reference_paper)

formatted_results = pd.DataFrame(index=functions, columns=pd.MultiIndex.from_product([papers, ['F', 'STD', '+/-/=']]))

for function in functions:
    formatted_results.loc[function, (reference_paper, 'F')] = means.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, 'STD')] = stds.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, '+/-/=')] = '='  # Indicate no comparison

for paper in papers:
    if paper == reference_paper:
        continue  # Skip comparison logic for p10
    for function in functions:
        data_ref = means.loc[function, reference_paper]
        data_comp = means.loc[function, paper]
        std_ref = stds.loc[function, reference_paper]
        std_comp = stds.loc[function, paper]

        try:
            stat, p_value = wilcoxon(means.loc[:, reference_paper].dropna(), means.loc[:, paper].dropna(), alternative='two-sided')
            if p_value <= 0.05:
                symbol = '-' if data_ref > data_comp else '+'
            else:
                symbol = '='
        except Exception as e:
            symbol = 'Err'
            print(f"Error: {e}")

        formatted_results.loc[function, (paper, 'F')] = data_comp
        formatted_results.loc[function, (paper, 'STD')] = std_comp
        formatted_results.loc[function, (paper, '+/-/=')] = symbol

formatted_results.to_csv('formatted_wilcoxon_results_control_p10_2.csv')
print(formatted_results.head())
# Out:
#                                                    p1                     \
#                                                     F                STD
# f1                                 149636019607.84314  9860362383.449652
# f2  2750838582077583239078808107687577659813295494...                inf
# f3                                      562208.803922       42074.314398
# f4                                       29268.207843         2968.33346
# f5                                        1363.152745          27.449553
#
#                                                          p2  \
#    +/-/=                                                  F
# f1     +                                124546971960.784317
# f2     +  1298572115421746445845094253941726103457111206...
# f3     +                                      601768.266078
# f4     +                                       23681.405098
# f5     +                                        1274.805878
#
#                                             p3                          \
#                    STD +/-/=                 F               STD +/-/=
# f1  10570851039.614445     +  5848022745.09804  821174864.934569     =
# f2                 inf     +      25896.584314        885.496184     =
# f3        94506.467135     +     161349.803922      21372.495171     =
# f4         4944.197726     +  801555921.568627  118634118.199175     =
# f5           39.292106     +    2523882.941176     836327.398288     =
#
#                                                    p4  ...    p9  \
#                                                     F  ... +/-/=
# f1                                      822877.363314  ...     +
# f2  2787372714238130151749228053989561887127090232...  ...     +
# f3                                      821282.191379  ...     +
# f4                                         283.919235  ...     +
# f5                                         449.464068  ...     +
#
#                                                   p10  \
#                                                     F
# f1                                       12324.501961
# f2  1050116246602099922265408688909109924085389356...
# f3                                      534803.921569
# f4                                         333.176471
# f5                                         795.901961
#
#                                                              \
#                                                   STD +/-/=
# f1                                        13187.90785     =
# f2  7403412458073657607013137812363883438977294605...     =
# f3                                       60588.622373     =
# f4                                          55.980986     =
# f5                                          78.592335     =
#
#                                                   p11                      \
#                                                     F                 STD
# f1                                195748820392.156891  13911681597.741837
# f2  4431476949011031669516035864937519328219989700...                 inf
# f3                                      581536.324706        71460.987483
# f4                                       43535.661824         4512.825348
# f5                                        1490.078157           34.765731
#
#                                                         p12  \
#    +/-/=                                                  F
# f1     +                                 86435705531.372543
# f2     +  4957855455176402965532847606002055810184504658...
# f3     +                                      344914.739157
# f4     +                                       14026.221714
# f5     +                                        1079.967983
#
#
#                                                   STD +/-/=
# f1                                  8705138204.964399     +
# f2  1708353521489469323352505335792590574710404640...     +
# f3                                       25606.626283     -
# f4                                        1905.604613     +
# f5                                          41.358925     +
#
# [5 rows x 33 columns]

# %%
wilcoxon_results = pd.read_csv('formatted_wilcoxon_results_control_p10_2.csv')

wilcoxon_results.head(10)
# Out:
#   Unnamed: 0                      p1                p1.1   p1.2  \
# 0        NaN                       F                 STD  +/-/=
# 1         f1      149636019607.84314   9860362383.449652      +
# 2         f2  2.750838582077583e+157                 inf      +
# 3         f3       562208.8039215687   42074.31439774135      +
# 4         f4      29268.207843137257   2968.333460328066      +
# 5         f5       1363.152745098039  27.449553307443114      +
# 6         f6       91.70968235294116   3.751970898582001      +
# 7         f7      3398.2807843137257  130.40388456326284      +
# 8         f8      1380.3721568627452   47.73719420990532      +
# 9         f9       73051.25294117647   4924.729129979416      +
#
#                         p2                p2.1   p2.2                  p3  \
# 0                        F                 STD  +/-/=                   F
# 1       124546971960.78432  10570851039.614445      +    5848022745.09804
# 2  1.2985721154217464e+159                 inf      +   25896.58431372549
# 3        601768.2660784314    94506.4671345462      +   161349.8039215686
# 4        23681.40509803921    4944.19772646708      +   801555921.5686275
# 5       1274.8058784313723   39.29210600561137      +  2523882.9411764704
# 6        81.53621237254902   3.802435890443924      +   6480439.607843137
# 7        3086.335092156862  157.93266352056108      +  521593.01960784313
# 8        1288.869007843137  48.622653262106105      +   7015.161960784313
# 9        54873.99301960783   5909.169815681883      +   4244.701568627451
#
#                  p3.1   p3.2  ...   p9.2                     p10  \
# 0                 STD  +/-/=  ...  +/-/=                       F
# 1    821174864.934569      =  ...      +      12324.501960784311
# 2   885.4961840182056      =  ...      +  1.0501162466020999e+83
# 3  21372.495171221963      =  ...      +       534803.9215686275
# 4  118634118.19917493      =  ...      +       333.1764705882353
# 5   836327.3982876823      =  ...      +       795.9019607843137
# 6  1984771.8773149317      =  ...      +      24.409803921568624
# 7   373774.6790271154      =  ...      -      1885.0980392156864
# 8  461.26917481168135      =  ...      +       861.4313725490196
# 9   296.6652968422167      =  ...      +      22652.941176470587
#
#                    p10.1  p10.2                      p11               p11.1  \
# 0                    STD  +/-/=                        F                 STD
# 1     13187.907850345782      =        195748820392.1569  13911681597.741837
# 2  7.403412458073658e+83      =  4.4314769490110317e+161                 inf
# 3     60588.622373279686      =        581536.3247058823   71460.98748332485
# 4      55.98098622671632      =        43535.66182352942  4512.8253478571305
# 5      78.59233483104151      =       1490.0781568627451   34.76573129670945
# 6      5.426559770420427      =        99.60964509803922   3.772181331560188
# 7      404.3119187498856      =       4067.0160411764714   257.1565316005403
# 8      68.67492475622359      =       1539.1935215686276   37.57105256673909
# 9     2569.6076561108925      =         84675.7218627451   6659.727854245898
#
#    p11.2                     p12                    p12.1  p12.2
# 0  +/-/=                       F                      STD  +/-/=
# 1      +       86435705531.37254          8705138204.9644      +
# 2      +  4.957855455176403e+137  1.7083535214894693e+138      +
# 3      +       344914.7391568628       25606.626283389807      -
# 4      +      14026.221713725488        1905.604612733696      +
# 5      +      1079.9679828431372        41.35892462242934      +
# 6      +       78.73989250980392        4.622345449005943      +
# 7      +      2018.2209670588236        164.9633573843645      +
# 8      +      1144.5866824509803        46.48586793880501      +
# 9      +       53648.49219019608        3675.825629205642      +
#
# [10 rows x 34 columns]

# %% [markdown]
# ## Counting superior performances

# %%
data_wilcoxon = pd.read_csv('formatted_wilcoxon_results_control_p10_2.csv')
print(data_wilcoxon.head())

results = {}
comparison_columns = [col for col in data_wilcoxon.columns if col.endswith('.2')]

for col in comparison_columns:
    paper = col.split('.')[0]
    results[paper] = 0

for index, row in data_wilcoxon.iterrows():
    for col in comparison_columns:
        paper = col.split('.')[0]
        symbol = row[col]
        if symbol == '-':
            results[paper] += 1

print("Number of times each paper was better than the control (p10):")
for paper, count in results.items():
    print(f"{paper}: {count}")
# Out:
#   Unnamed: 0                      p1               p1.1   p1.2  \
# 0        NaN                       F                STD  +/-/=
# 1         f1      149636019607.84314  9860362383.449652      +
# 2         f2  2.750838582077583e+157                inf      +
# 3         f3       562208.8039215687  42074.31439774135      +
# 4         f4      29268.207843137257  2968.333460328066      +
#
#                         p2                p2.1   p2.2                 p3  \
# 0                        F                 STD  +/-/=                  F
# 1       124546971960.78432  10570851039.614445      +   5848022745.09804
# 2  1.2985721154217464e+159                 inf      +  25896.58431372549
# 3        601768.2660784314    94506.4671345462      +  161349.8039215686
# 4        23681.40509803921    4944.19772646708      +  801555921.5686275
#
#                  p3.1   p3.2  ...   p9.2                     p10  \
# 0                 STD  +/-/=  ...  +/-/=                       F
# 1    821174864.934569      =  ...      +      12324.501960784311
# 2   885.4961840182056      =  ...      +  1.0501162466020999e+83
# 3  21372.495171221963      =  ...      +       534803.9215686275
# 4  118634118.19917493      =  ...      +       333.1764705882353
#
#                    p10.1  p10.2                      p11               p11.1  \
# 0                    STD  +/-/=                        F                 STD
# 1     13187.907850345782      =        195748820392.1569  13911681597.741837
# 2  7.403412458073658e+83      =  4.4314769490110317e+161                 inf
# 3     60588.622373279686      =        581536.3247058823   71460.98748332485
# 4      55.98098622671632      =        43535.66182352942  4512.8253478571305
#
#    p11.2                     p12                    p12.1  p12.2
# 0  +/-/=                       F                      STD  +/-/=
# 1      +       86435705531.37254          8705138204.9644      +
# 2      +  4.957855455176403e+137  1.7083535214894693e+138      +
# 3      +       344914.7391568628       25606.626283389807      -
# 4      +      14026.221713725488        1905.604612733696      +
#
# [5 rows x 34 columns]
# Number of times each paper was better than the control (p10):
# p1: 0
# p2: 0
# p3: 0
# p4: 0
# p5: 1
# p7: 1
# p8: 0
# p9: 2
# p10: 0
# p11: 0
# p12: 1

# %% [markdown]
# ## Wilcoxon Summary

# %%
import pandas as pd
from scipy.stats import wilcoxon

data = pd.read_csv('Dim 100_2.csv')

control = 'p10'
algorithms = [col for col in data.columns[1:13] if col != control]

results_list = []

for alg in algorithms:
    data_control = data[control].dropna().astype(float)
    data_alg = data[alg].dropna().astype(float)
    
    if len(data_control) > 0 and len(data_alg) > 0:
        stat, p_value = wilcoxon(data_control, data_alg, alternative='two-sided')
        better_count = sum(data_alg > data_control)
        worse_count = sum(data_alg < data_control)
        equal_count = sum(data_alg == data_control)
        
        l_value = '+' if better_count > worse_count else '-' if worse_count > better_count else '='
        
        results_list.append({
            'Proposed algorithm': alg,
            'R+': better_count,
            'R-': worse_count,
            'R=': equal_count,
            'P-value': f"{p_value:.2E}" if p_value is not None else "N/A",
            'L-value': l_value
        })

results = pd.DataFrame(results_list)


results.to_csv('wilcoxon_summary_results_control_p10_2.csv', index=False)

results
# Out:
#   Proposed algorithm  R+  R-  R=   P-value L-value
# 0                 p1  30   0   0  1.86E-09       +
# 1                 p2  30   0   0  1.86E-09       +
# 2                 p3  15  15   0  6.12E-01       =
# 3                 p4  11  19   0  3.93E-01       -
# 4                 p5  29   1   0  3.79E-06       +
# 5                 p7  29   1   0  5.72E-07       +
# 6                 p8  30   0   0  1.86E-09       +
# 7                 p9  28   2   0  1.64E-07       +
# 8                p11  30   0   0  1.86E-09       +
# 9                p12  29   1   0  8.33E-07       +

# %% [markdown]
# # Dim 100_03

# %%
import pandas as pd
from scipy.stats import wilcoxon

means = pd.read_csv('Dim 100_3.csv', index_col=0)
stds = pd.read_csv('Dim 100_std_3.csv', index_col=0)

functions = means.index.tolist()
papers = means.columns.tolist()

reference_paper = 'p10'

if reference_paper not in papers:
    papers.append(reference_paper)

formatted_results = pd.DataFrame(index=functions, columns=pd.MultiIndex.from_product([papers, ['F', 'STD', '+/-/=']]))

for function in functions:
    formatted_results.loc[function, (reference_paper, 'F')] = means.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, 'STD')] = stds.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, '+/-/=')] = '='  # Indicate no comparison

for paper in papers:
    if paper == reference_paper:
        continue  # Skip comparison logic for p10
    for function in functions:
        data_ref = means.loc[function, reference_paper]
        data_comp = means.loc[function, paper]
        std_ref = stds.loc[function, reference_paper]
        std_comp = stds.loc[function, paper]

        try:
            stat, p_value = wilcoxon(means.loc[:, reference_paper].dropna(), means.loc[:, paper].dropna(), alternative='two-sided')
            if p_value <= 0.05:
                symbol = '-' if data_ref > data_comp else '+'
            else:
                symbol = '='
        except Exception as e:
            symbol = 'Err'
            print(f"Error: {e}")

        formatted_results.loc[function, (paper, 'F')] = data_comp
        formatted_results.loc[function, (paper, 'STD')] = std_comp
        formatted_results.loc[function, (paper, '+/-/=')] = symbol

formatted_results.to_csv('formatted_wilcoxon_results_control_p10_3.csv')
print(formatted_results.head())
# Out:
#                                                    p1  \
#                                                     F
# f1                                 89749903921.568634
# f2  9637805264855608653761073131337181613109477282...
# f3                                      519326.843137
# f4                                       14428.601961
# f5                                        1203.339804
#
#                                                              \
#                                                   STD +/-/=
# f1                                  4500728996.200452     +
# f2  3548922485694675740750474724822373130621623929...     +
# f3                                       51662.146331     +
# f4                                        1481.638471     +
# f5                                          28.618212     +
#
#                                                    p2                     \
#                                                     F                STD
# f1                                  74011449607.84314  6091551883.849594
# f2  1250939784846143973528022249253385363243443563...                inf
# f3                                      539586.032745       94547.787265
# f4                                        10325.17368        1777.495902
# f5                                        1106.862233          32.410249
#
#                          p3                          \
#    +/-/=                  F               STD +/-/=
# f1     +  1342466294.117647  283033961.493524     =
# f2     +       24892.188235        866.097111     =
# f3     +      134723.666667      13163.340374     =
# f4     +   255141980.392157   50600018.115741     =
# f5     +       92647.690196      42695.343203     =
#
#                                                    p4  ...    p9  \
#                                                     F  ... +/-/=
# f1                                        16162.96076  ...     +
# f2  3804993901369774094092287459825775845679666612...  ...     +
# f3                                       804072.38096  ...     +
# f4                                         246.688415  ...     +
# f5                                         146.555914  ...     +
#
#                                                   p10  \
#                                                     F
# f1                                       12322.513725
# f2  1384594391878728643569294004474877333140112491...
# f3                                      480607.843137
# f4                                          285.45098
# f5                                         795.882353
#
#                                                              \
#                                                   STD +/-/=
# f1                                       13185.965957     =
# f2  6870239488403080727306688091437362935080169177...     =
# f3                                       56087.843719     =
# f4                                          50.815434     =
# f5                                          78.614135     =
#
#                                                   p11                     \
#                                                     F                STD
# f1                                133047998627.450958  6213397675.142542
# f2  1331605900444835614774944134217867449089155176...                inf
# f3                                      549150.599608       71404.496389
# f4                                       23988.494157        2223.711293
# f5                                        1317.555365          35.779739
#
#                                                         p12  \
#    +/-/=                                                  F
# f1     +                                 46447321929.411766
# f2     +  7757566250351019269075516502618665823402067159...
# f3     +                                       328590.25151
# f4     +                                        6404.099304
# f5     +                                         977.311705
#
#
#                                                   STD +/-/=
# f1                                  6032297034.465304     +
# f2  4264289638803743904591351560125910344273008279...     +
# f3                                       22239.178402     -
# f4                                         960.889357     +
# f5                                          38.281867     +
#
# [5 rows x 33 columns]

# %%
wilcoxon_results = pd.read_csv('formatted_wilcoxon_results_control_p10_3.csv')

wilcoxon_results.head(10)
# Out:
#   Unnamed: 0                      p1                     p1.1   p1.2  \
# 0        NaN                       F                      STD  +/-/=
# 1         f1       89749903921.56863        4500728996.200452      +
# 2         f2  9.637805264855609e+148  3.5489224856946757e+149      +
# 3         f3       519326.8431372549         51662.1463307982      +
# 4         f4      14428.601960784315       1481.6384705612688      +
# 5         f5      1203.3398039215683       28.618211704053497      +
# 6         f6       76.12524117647058        2.791142440859521      +
# 7         f7       2367.507843137255       114.38237765878692      +
# 8         f8      1215.7731372549017        34.74706197145059      +
# 9         f9       50246.48431372549       4317.9316641448295      +
#
#                        p2                p2.1   p2.2                  p3  \
# 0                       F                 STD  +/-/=                   F
# 1       74011449607.84314   6091551883.849594      +  1342466294.1176472
# 2  1.250939784846144e+157                 inf      +  24892.188235294117
# 3        539586.032745098   94547.78726512144      +  134723.66666666666
# 4      10325.173680392158   1777.495901899685      +  255141980.39215687
# 5      1106.8622333333335  32.410249214139256      +   92647.69019607842
# 6       61.87606892156863   3.505837280264478      +   4164366.470588235
# 7       2254.812419607844  115.43914128388516      +   74645.35098039216
# 8       1122.122619607843   40.87074537919498      +   6157.938431372549
# 9       34183.08056862745   5134.357099046481      +   3731.819215686274
#
#                  p3.1   p3.2  ...   p9.2                     p10  \
# 0                 STD  +/-/=  ...  +/-/=                       F
# 1  283033961.49352366      =  ...      +      12322.513725490197
# 2   866.0971105826591      =  ...      +  1.3845943918787286e+70
# 3   13163.34037358488      =  ...      +       480607.8431372549
# 4   50600018.11574123      =  ...      +      285.45098039215685
# 5   42695.34320342371      =  ...      +       795.8823529411765
# 6   1153753.464250442      =  ...      +      24.152941176470588
# 7  56477.376659891735      =  ...      -       1683.529411764706
# 8   391.9439141068305      =  ...      +       861.4313725490196
# 9   315.3352507290075      =  ...      +       22556.86274509804
#
#                    p10.1  p10.2                      p11               p11.1  \
# 0                    STD  +/-/=                        F                 STD
# 1       13185.9659574484      =       133047998627.45096   6213397675.142542
# 2  6.870239488403081e+70      =  1.3316059004448356e+157                 inf
# 3      56087.84371853675      =         549150.599607843   71404.49638870286
# 4       50.8154344800059      =       23988.494156862747  2223.7112928352008
# 5        78.614135100508      =        1317.555364705882   35.77973899619741
# 6      5.451905690967742      =        86.18246760784312   3.770069957631935
# 7     344.58172159944627      =         3488.98537254902   121.6322883785517
# 8      68.67492475622359      =        1337.538723529412   34.78173343531528
# 9      2556.134865719985      =         67074.8225490196   4966.101747381835
#
#    p11.2                     p12                   p12.1  p12.2
# 0  +/-/=                       F                     STD  +/-/=
# 1      +      46447321929.411766       6032297034.465304      +
# 2      +  7.757566250351019e+130  4.264289638803744e+131      +
# 3      +        328590.251509804      22239.178402009507      -
# 4      +       6404.099303529411       960.8893565760972      +
# 5      +       977.3117050980392      38.281866589771454      +
# 6      +       73.08343562745098       4.392692618206763      +
# 7      +      1793.1833196078428      172.43039325897522      +
# 8      +      1047.2419374509805       49.01466766416203      +
# 9      +       51076.91638235295       3546.675664356933      +
#
# [10 rows x 34 columns]

# %% [markdown]
# ## Counting superior performances

# %%
data_wilcoxon = pd.read_csv('formatted_wilcoxon_results_control_p10_3.csv')
print(data_wilcoxon.head())

results = {}
comparison_columns = [col for col in data_wilcoxon.columns if col.endswith('.2')]

for col in comparison_columns:
    paper = col.split('.')[0]
    results[paper] = 0

for index, row in data_wilcoxon.iterrows():
    for col in comparison_columns:
        paper = col.split('.')[0]
        symbol = row[col]
        if symbol == '-':
            results[paper] += 1

print("Number of times each paper was better than the control (p10):")
for paper, count in results.items():
    print(f"{paper}: {count}")
# Out:
#   Unnamed: 0                      p1                     p1.1   p1.2  \
# 0        NaN                       F                      STD  +/-/=
# 1         f1       89749903921.56863        4500728996.200452      +
# 2         f2  9.637805264855609e+148  3.5489224856946757e+149      +
# 3         f3       519326.8431372549         51662.1463307982      +
# 4         f4      14428.601960784315       1481.6384705612688      +
#
#                        p2               p2.1   p2.2                  p3  \
# 0                       F                STD  +/-/=                   F
# 1       74011449607.84314  6091551883.849594      +  1342466294.1176472
# 2  1.250939784846144e+157                inf      +  24892.188235294117
# 3        539586.032745098  94547.78726512144      +  134723.66666666666
# 4      10325.173680392158  1777.495901899685      +  255141980.39215687
#
#                  p3.1   p3.2  ...   p9.2                     p10  \
# 0                 STD  +/-/=  ...  +/-/=                       F
# 1  283033961.49352366      =  ...      +      12322.513725490197
# 2   866.0971105826591      =  ...      +  1.3845943918787286e+70
# 3   13163.34037358488      =  ...      +       480607.8431372549
# 4   50600018.11574123      =  ...      +      285.45098039215685
#
#                    p10.1  p10.2                      p11               p11.1  \
# 0                    STD  +/-/=                        F                 STD
# 1       13185.9659574484      =       133047998627.45096   6213397675.142542
# 2  6.870239488403081e+70      =  1.3316059004448356e+157                 inf
# 3      56087.84371853675      =         549150.599607843   71404.49638870286
# 4       50.8154344800059      =       23988.494156862747  2223.7112928352008
#
#    p11.2                     p12                   p12.1  p12.2
# 0  +/-/=                       F                     STD  +/-/=
# 1      +      46447321929.411766       6032297034.465304      +
# 2      +  7.757566250351019e+130  4.264289638803744e+131      +
# 3      +        328590.251509804      22239.178402009507      -
# 4      +       6404.099303529411       960.8893565760972      +
#
# [5 rows x 34 columns]
# Number of times each paper was better than the control (p10):
# p1: 0
# p2: 0
# p3: 0
# p4: 0
# p5: 1
# p7: 1
# p8: 0
# p9: 2
# p10: 0
# p11: 0
# p12: 1

# %% [markdown]
# ## Wilcoxon Summary

# %%
import pandas as pd
from scipy.stats import wilcoxon

data = pd.read_csv('Dim 100_3.csv')

control = 'p10'
algorithms = [col for col in data.columns[1:13] if col != control]

results_list = []

for alg in algorithms:
    data_control = data[control].dropna().astype(float)
    data_alg = data[alg].dropna().astype(float)
    
    if len(data_control) > 0 and len(data_alg) > 0:
        stat, p_value = wilcoxon(data_control, data_alg, alternative='two-sided')
        better_count = sum(data_alg > data_control)
        worse_count = sum(data_alg < data_control)
        equal_count = sum(data_alg == data_control)
        
        l_value = '+' if better_count > worse_count else '-' if worse_count > better_count else '='
        
        results_list.append({
            'Proposed algorithm': alg,
            'R+': better_count,
            'R-': worse_count,
            'R=': equal_count,
            'P-value': f"{p_value:.2E}" if p_value is not None else "N/A",
            'L-value': l_value
        })

results = pd.DataFrame(results_list)


results.to_csv('wilcoxon_summary_results_control_p10_3.csv', index=False)

results
# Out:
#   Proposed algorithm  R+  R-  R=   P-value L-value
# 0                 p1  30   0   0  1.86E-09       +
# 1                 p2  30   0   0  1.86E-09       +
# 2                 p3  14  16   0  7.30E-01       -
# 3                 p4  11  19   0  4.40E-01       -
# 4                 p5  29   1   0  3.79E-06       +
# 5                 p7  29   1   0  5.72E-07       +
# 6                 p8  30   0   0  1.86E-09       +
# 7                 p9  28   2   0  4.71E-07       +
# 8                p11  30   0   0  1.86E-09       +
# 9                p12  29   1   0  8.33E-07       +

# %% [markdown]
# # Dim 100_04

# %%
import pandas as pd
from scipy.stats import wilcoxon

means = pd.read_csv('Dim 100_4.csv', index_col=0)
stds = pd.read_csv('Dim 100_std_4.csv', index_col=0)

functions = means.index.tolist()
papers = means.columns.tolist()

reference_paper = 'p10'

if reference_paper not in papers:
    papers.append(reference_paper)

formatted_results = pd.DataFrame(index=functions, columns=pd.MultiIndex.from_product([papers, ['F', 'STD', '+/-/=']]))

for function in functions:
    formatted_results.loc[function, (reference_paper, 'F')] = means.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, 'STD')] = stds.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, '+/-/=')] = '='  # Indicate no comparison

for paper in papers:
    if paper == reference_paper:
        continue  # Skip comparison logic for p10
    for function in functions:
        data_ref = means.loc[function, reference_paper]
        data_comp = means.loc[function, paper]
        std_ref = stds.loc[function, reference_paper]
        std_comp = stds.loc[function, paper]

        try:
            stat, p_value = wilcoxon(means.loc[:, reference_paper].dropna(), means.loc[:, paper].dropna(), alternative='two-sided')
            if p_value <= 0.05:
                symbol = '-' if data_ref > data_comp else '+'
            else:
                symbol = '='
        except Exception as e:
            symbol = 'Err'
            print(f"Error: {e}")

        formatted_results.loc[function, (paper, 'F')] = data_comp
        formatted_results.loc[function, (paper, 'STD')] = std_comp
        formatted_results.loc[function, (paper, '+/-/=')] = symbol

formatted_results.to_csv('formatted_wilcoxon_results_control_p10_4.csv')
print(formatted_results.head())
# Out:
#                                                    p1  \
#                                                     F
# f1                                 31668782352.941177
# f2  2172584149974263705874181380833014532252169333...
# f3                                      479411.901961
# f4                                        4210.915686
# f5                                        1045.845333
#
#                                                              \
#                                                   STD +/-/=
# f1                                  2183229479.886492     +
# f2  8155608535034820882674661509234130723599324822...     +
# f3                                       38240.969901     +
# f4                                         431.043423     +
# f5                                          26.843303     +
#
#                                                    p2  \
#                                                     F
# f1                                  21805440529.41177
# f2  8177365699499209354231321603984165179888767086...
# f3                                      431742.286078
# f4                                        2416.681757
# f5                                          954.59684
#
#                                                                            p3  \
#                                                   STD +/-/=                 F
# f1                                    2045591781.0278     +  125595933.333333
# f2  4610879365617825035141853978805694430574081017...     +      23215.543137
# f3                                       65755.357737     +      94749.178431
# f4                                         311.607421     +        57371400.0
# f5                                          21.913095     +       6816.687451
#
#                                                                           p4  \
#                 STD +/-/=                                                  F
# f1  38665078.252613     =                                       15796.956429
# f2       856.369653     =  2191850968212900773653005601096837771203100050...
# f3     10162.976679     =                                      769101.883576
# f4  12119450.428442     =                                         231.657627
# f5      3217.657021     =                                         145.810057
#
#     ...    p9                                                p10  \
#     ... +/-/=                                                  F
# f1  ...     +                                       12319.964706
# f2  ...     +  5745517962115015572250798332344344101240410472...
# f3  ...     +                                      428215.686275
# f4  ...     +                                         256.764706
# f5  ...     +                                         781.333333
#
#                                                              \
#                                                   STD +/-/=
# f1                                        13181.51828     =
# f2  4062391853733201972328688172615205157104016141...     =
# f3                                       49313.448719     =
# f4                                          42.858448     =
# f5                                          85.365803     =
#
#                                                   p11  \
#                                                     F
# f1                                 50078862725.490196
# f2  2220132194944472384493172742580047082664018698...
# f3                                      455471.526667
# f4                                        7018.208284
# f5                                        1101.647335
#
#                                                              \
#                                                   STD +/-/=
# f1                                  2778622474.022307     +
# f2  1543897883058410619011686957219322970411998975...     +
# f3                                       69085.622132     +
# f4                                         624.165821     +
# f5                                          23.019297     +
#
#                                                   p12  \
#                                                     F
# f1                                  9387507531.764706
# f2  5294256444039170978337630291200328659388570421...
# f3                                      308161.575824
# f4                                        1706.677235
# f5                                         851.963948
#
#
#                                                   STD +/-/=
# f1                                  1962979229.881702     +
# f2  3743021055608557366644468176397973839943603586...     +
# f3                                       20830.197089     -
# f4                                         224.856984     +
# f5                                          35.535609     +
#
# [5 rows x 33 columns]

# %%
wilcoxon_results = pd.read_csv('formatted_wilcoxon_results_control_p10_4.csv')

wilcoxon_results.head(10)
# Out:
#   Unnamed: 0                       p1                    p1.1   p1.2  \
# 0        NaN                        F                     STD  +/-/=
# 1         f1       31668782352.941177      2183229479.8864923      +
# 2         f2  2.1725841499742637e+141  8.155608535034821e+141      +
# 3         f3       479411.90196078434       38240.96990076445      +
# 4         f4        4210.915686274509       431.0434227398373      +
# 5         f5       1045.8453333333334       26.84330291961082      +
# 6         f6        53.73197843137255      2.6264551592693226      +
# 7         f7       1474.6231372549023       50.69811906207312      +
# 8         f8       1062.7574509803922      24.870678368755996      +
# 9         f9       25246.852941176465       2294.390295221167      +
#
#                        p2                    p2.1   p2.2                  p3  \
# 0                       F                     STD  +/-/=                   F
# 1       21805440529.41177         2045591781.0278      +  125595933.33333331
# 2  8.177365699499209e+130  4.610879365617825e+131      +  23215.543137254903
# 3       431742.2860784313       65755.35773694365      +   94749.17843137254
# 4       2416.681756862745      311.60742094428423      +          57371400.0
# 5       954.5968396078432      21.913094750075985      +   6816.687450980392
# 6       35.83351380392157      1.6724285257182496      +   2220535.549019608
# 7      1422.9522294117644       36.63139372326342      +  12977.989803921568
# 8       948.7385970588236      30.820490134068304      +  5210.9960784313735
# 9      11535.123870588235       945.6801237236216      +  3214.2576470588237
#
#                  p3.1   p3.2  ...   p9.2                     p10  \
# 0                 STD  +/-/=  ...  +/-/=                       F
# 1   38665078.25261257      =  ...      +      12319.964705882352
# 2   856.3696526972134      =  ...      +  5.7455179621150156e+57
# 3  10162.976678858658      =  ...      +       428215.6862745098
# 4  12119450.428441504      =  ...      +       256.7647058823529
# 5  3217.6570206198926      =  ...      +       781.3333333333334
# 6   674813.2869531558      =  ...      +      22.358823529411765
# 7   8826.525350367512      =  ...      +      1180.6666666666667
# 8   387.8321151699152      =  ...      +       834.0980392156863
# 9   298.3279281923865      =  ...      +       9416.470588235294
#
#                    p10.1  p10.2                      p11  \
# 0                    STD  +/-/=                        F
# 1     13181.518279636886      =         50078862725.4902
# 2  4.062391853733202e+58      =  2.2201321949444724e+150
# 3      49313.44871867134      =       455471.52666666656
# 4      42.85844837908291      =        7018.208284313724
# 5      85.36580264624651      =       1101.6473352941175
# 6      4.982722166100013      =        60.19492158823529
# 7      339.0472039937031      =        2046.659676470588
# 8      96.10293805101736      =       1108.3289166666668
# 9      7730.310300833606      =         33016.3351372549
#
#                      p11.1  p11.2                     p12  \
# 0                      STD  +/-/=                       F
# 1        2778622474.022307      +       9387507531.764706
# 2  1.5438978830584106e+151      +  5.294256444039171e+120
# 3         69085.6221317803      +      308161.57582352945
# 4        624.1658210454025      +       1706.677234509804
# 5       23.019297488623216      +       851.9639484117646
# 6       1.7469107178955994      +       65.57700154901961
# 7        67.65400979082537      +      1565.3167692156865
# 8       31.679236146310306      +       916.0385845294117
# 9        2365.412444691192      +       46557.00894901961
#
#                      p12.1  p12.2
# 0                      STD  +/-/=
# 1       1962979229.8817017      +
# 2  3.7430210556085574e+121      +
# 3       20830.197089168367      -
# 4       224.85698446853863      +
# 5        35.53560934835441      +
# 6        3.886607107690194      +
# 7       138.07723465699252      +
# 8       49.438280142916376      +
# 9       3358.9941154296894      +
#
# [10 rows x 34 columns]

# %% [markdown]
# ## Counting superior performances

# %%
data_wilcoxon = pd.read_csv('formatted_wilcoxon_results_control_p10_4.csv')
print(data_wilcoxon.head())

results = {}
comparison_columns = [col for col in data_wilcoxon.columns if col.endswith('.2')]

for col in comparison_columns:
    paper = col.split('.')[0]
    results[paper] = 0

for index, row in data_wilcoxon.iterrows():
    for col in comparison_columns:
        paper = col.split('.')[0]
        symbol = row[col]
        if symbol == '-':
            results[paper] += 1

print("Number of times each paper was better than the control (p10):")
for paper, count in results.items():
    print(f"{paper}: {count}")
# Out:
#   Unnamed: 0                       p1                    p1.1   p1.2  \
# 0        NaN                        F                     STD  +/-/=
# 1         f1       31668782352.941177      2183229479.8864923      +
# 2         f2  2.1725841499742637e+141  8.155608535034821e+141      +
# 3         f3       479411.90196078434       38240.96990076445      +
# 4         f4        4210.915686274509       431.0434227398373      +
#
#                        p2                    p2.1   p2.2                  p3  \
# 0                       F                     STD  +/-/=                   F
# 1       21805440529.41177         2045591781.0278      +  125595933.33333331
# 2  8.177365699499209e+130  4.610879365617825e+131      +  23215.543137254903
# 3       431742.2860784313       65755.35773694365      +   94749.17843137254
# 4       2416.681756862745      311.60742094428423      +          57371400.0
#
#                  p3.1   p3.2  ...   p9.2                     p10  \
# 0                 STD  +/-/=  ...  +/-/=                       F
# 1   38665078.25261257      =  ...      +      12319.964705882352
# 2   856.3696526972134      =  ...      +  5.7455179621150156e+57
# 3  10162.976678858658      =  ...      +       428215.6862745098
# 4  12119450.428441504      =  ...      +       256.7647058823529
#
#                    p10.1  p10.2                      p11  \
# 0                    STD  +/-/=                        F
# 1     13181.518279636886      =         50078862725.4902
# 2  4.062391853733202e+58      =  2.2201321949444724e+150
# 3      49313.44871867134      =       455471.52666666656
# 4      42.85844837908291      =        7018.208284313724
#
#                      p11.1  p11.2                     p12  \
# 0                      STD  +/-/=                       F
# 1        2778622474.022307      +       9387507531.764706
# 2  1.5438978830584106e+151      +  5.294256444039171e+120
# 3         69085.6221317803      +      308161.57582352945
# 4        624.1658210454025      +       1706.677234509804
#
#                      p12.1  p12.2
# 0                      STD  +/-/=
# 1       1962979229.8817017      +
# 2  3.7430210556085574e+121      +
# 3       20830.197089168367      -
# 4       224.85698446853863      +
#
# [5 rows x 34 columns]
# Number of times each paper was better than the control (p10):
# p1: 0
# p2: 0
# p3: 0
# p4: 0
# p5: 1
# p7: 1
# p8: 0
# p9: 2
# p10: 0
# p11: 0
# p12: 3

# %% [markdown]
# ## Wilcoxon Summary

# %%
import pandas as pd
from scipy.stats import wilcoxon

data = pd.read_csv('Dim 100_4.csv')

control = 'p10'
algorithms = [col for col in data.columns[1:13] if col != control]

results_list = []

for alg in algorithms:
    data_control = data[control].dropna().astype(float)
    data_alg = data[alg].dropna().astype(float)
    
    if len(data_control) > 0 and len(data_alg) > 0:
        stat, p_value = wilcoxon(data_control, data_alg, alternative='two-sided')
        better_count = sum(data_alg > data_control)
        worse_count = sum(data_alg < data_control)
        equal_count = sum(data_alg == data_control)
        
        l_value = '+' if better_count > worse_count else '-' if worse_count > better_count else '='
        
        results_list.append({
            'Proposed algorithm': alg,
            'R+': better_count,
            'R-': worse_count,
            'R=': equal_count,
            'P-value': f"{p_value:.2E}" if p_value is not None else "N/A",
            'L-value': l_value
        })

results = pd.DataFrame(results_list)


results.to_csv('wilcoxon_summary_results_control_p10_4.csv', index=False)

results
# Out:
#   Proposed algorithm  R+  R-  R=   P-value L-value
# 0                 p1  30   0   0  1.86E-09       +
# 1                 p2  30   0   0  1.86E-09       +
# 2                 p3  13  17   0  8.87E-01       -
# 3                 p4  11  19   0  4.40E-01       -
# 4                 p5  29   1   0  3.79E-06       +
# 5                 p7  29   1   0  6.91E-07       +
# 6                 p8  30   0   0  1.86E-09       +
# 7                 p9  28   2   0  5.72E-07       +
# 8                p11  30   0   0  1.86E-09       +
# 9                p12  27   3   0  5.97E-06       +

# %% [markdown]
# # Dim 100_05

# %%
import pandas as pd
from scipy.stats import wilcoxon

means = pd.read_csv('Dim 100_5.csv', index_col=0)
stds = pd.read_csv('Dim 100_std_5.csv', index_col=0)

functions = means.index.tolist()
papers = means.columns.tolist()

reference_paper = 'p10'

if reference_paper not in papers:
    papers.append(reference_paper)

formatted_results = pd.DataFrame(index=functions, columns=pd.MultiIndex.from_product([papers, ['F', 'STD', '+/-/=']]))

for function in functions:
    formatted_results.loc[function, (reference_paper, 'F')] = means.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, 'STD')] = stds.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, '+/-/=')] = '='  # Indicate no comparison

for paper in papers:
    if paper == reference_paper:
        continue  # Skip comparison logic for p10
    for function in functions:
        data_ref = means.loc[function, reference_paper]
        data_comp = means.loc[function, paper]
        std_ref = stds.loc[function, reference_paper]
        std_comp = stds.loc[function, paper]

        try:
            stat, p_value = wilcoxon(means.loc[:, reference_paper].dropna(), means.loc[:, paper].dropna(), alternative='two-sided')
            if p_value <= 0.05:
                symbol = '-' if data_ref > data_comp else '+'
            else:
                symbol = '='
        except Exception as e:
            symbol = 'Err'
            print(f"Error: {e}")

        formatted_results.loc[function, (paper, 'F')] = data_comp
        formatted_results.loc[function, (paper, 'STD')] = std_comp
        formatted_results.loc[function, (paper, '+/-/=')] = symbol

formatted_results.to_csv('formatted_wilcoxon_results_control_p10_5.csv')
print(formatted_results.head())
# Out:
#                                                    p1  \
#                                                     F
# f1                                  1783023725.490196
# f2  1186996643035394265914082573431900238617397729...
# f3                                       387294.54902
# f4                                          679.82949
# f5                                         921.855529
#
#                                                              \
#                                                   STD +/-/=
# f1                                    188294652.43894     +
# f2  8226162113489821099082571186727510024445705389...     +
# f3                                       28669.142112     +
# f4                                          33.741029     +
# f5                                          26.822535     +
#
#                                                    p2  \
#                                                     F
# f1                                  1038731755.882353
# f2  7713740516748991226320667346759186185715769978...
# f3                                       351748.54098
# f4                                         476.231531
# f5                                         847.394773
#
#                                                                           p3  \
#                                                   STD +/-/=                F
# f1                                   109278082.023959     +    980734.941176
# f2  4963667671903422261146799938640999424000340877...     +     20934.992157
# f3                                       28470.423715     -     38703.519608
# f4                                          27.324845     +  12227358.431373
# f5                                          18.339836     +      2988.314235
#
#                                                                         p4  \
#               STD +/-/=                                                  F
# f1  381626.247169     =                                           0.000084
# f2     764.547945     =  2564796170405452971288523176958666316368136110...
# f3    5538.719077     =                                      708491.731377
# f4  3666662.96613     =                                         220.308546
# f5    2240.010268     =                                         137.219825
#
#     ...    p9                                                p10  \
#     ... +/-/=                                                  F
# f1  ...     +                                       12314.021569
# f2  ...     +  1066666666671879537174348150061699131834359108...
# f3  ...     +                                           362000.0
# f4  ...     +                                         229.058824
# f5  ...     -                                         695.568627
#
#                                                              \
#                                                   STD +/-/=
# f1                                       13177.815081     =
# f2  7542472332655771726301655340484434747729946179...     =
# f3                                       46909.591812     =
# f4                                          36.581047     =
# f5                                          94.616098     =
#
#                                                   p11  \
#                                                     F
# f1                                  4175805401.960784
# f2  4133850314986474170071155053138181485695279343...
# f3                                      381450.179804
# f4                                        1014.509271
# f5                                         940.437813
#
#                                                              \
#                                                   STD +/-/=
# f1                                   485994842.285226     +
# f2  2757028328841915115778347737072068273206412091...     +
# f3                                       27237.358068     +
# f4                                          52.872934     +
# f5                                          21.124565     +
#
#                                                   p12  \
#                                                     F
# f1                                   806148115.372549
# f2  1780030943576388653609113531696526930112376777...
# f3                                      280302.584196
# f4                                         625.889088
# f5                                         683.174627
#
#
#                                                   STD +/-/=
# f1                                   111990354.571052     +
# f2  1254679863686885579501556297666828965121585406...     +
# f3                                       19843.866787     -
# f4                                          62.375737     +
# f5                                          30.868338     -
#
# [5 rows x 33 columns]

# %%
wilcoxon_results = pd.read_csv('formatted_wilcoxon_results_control_p10_5.csv')

wilcoxon_results.head(10)
# Out:
#   Unnamed: 0                       p1                    p1.1   p1.2  \
# 0        NaN                        F                     STD  +/-/=
# 1         f1        1783023725.490196       188294652.4389397      +
# 2         f2  1.1869966430353943e+127  8.226162113489821e+127      +
# 3         f3       387294.54901960783       28669.14211175611      +
# 4         f4        679.8294901960784       33.74102871577753      +
# 5         f5        921.8555294117646       26.82253493989851      +
# 6         f6       22.132492156862742      1.4020443581753848      +
# 7         f7       1056.1812352941176      20.340462269014097      +
# 8         f8        923.5390392156864      19.753919664616163      +
# 9         f9       4168.4094117647055      501.24479893995897      -
#
#                        p2                    p2.1   p2.2                  p3  \
# 0                       F                     STD  +/-/=                   F
# 1       1038731755.882353       109278082.0239586      +   980734.9411764706
# 2  7.713740516748991e+104  4.963667671903422e+105      +  20934.992156862747
# 3      351748.54098039225      28470.423714832403      -   38703.51960784314
# 4        476.231531372549      27.324845158923505      +   12227358.43137255
# 5       847.3947725490195      18.339835923823102      +  2988.3142352941177
# 6      10.447591513725492      0.5300106335862222      -   702241.8627450981
# 7       989.8868574509802       17.23692426594083      +  2931.8913921568624
# 8       844.7674368627452      18.154008021454583      +   4059.851960784313
# 9       916.0663266666668       110.3863002290572      -   2601.710196078431
#
#                  p3.1   p3.2  ...   p9.2                     p10  \
# 0                 STD  +/-/=  ...  +/-/=                       F
# 1  381626.24716945714      =  ...      +      12314.021568627451
# 2   764.5479453394661      =  ...      +  1.0666666666718795e+51
# 3   5538.719077443016      =  ...      +                362000.0
# 4  3666662.9661295256      =  ...      +      229.05882352941177
# 5  2240.0102681122903      =  ...      -       695.5686274509804
# 6  161031.04418847983      =  ...      +      18.531372549019608
# 7  1604.6019829910674      =  ...      +       939.9803921568628
# 8   315.3579167718248      =  ...      -        706.843137254902
# 9   226.4761548933037      =  ...      +      6782.6274509803925
#
#                    p10.1  p10.2                     p11  \
# 0                    STD  +/-/=                       F
# 1     13177.815081316705      =       4175805401.960784
# 2  7.542472332655772e+51      =  4.133850314986474e+135
# 3      46909.59181150022      =       381450.1798039216
# 4     36.581047147131024      =      1014.5092711764704
# 5      94.61609839021422      =        940.437813137255
# 6      4.870901603382547      =       26.71660725490196
# 7      215.2429079422921      =      1149.4124823529412
# 8     145.06501213945552      =        938.460693529412
# 9      6829.561585449137      =       5121.301778431373
#
#                     p11.1  p11.2                     p12  \
# 0                     STD  +/-/=                       F
# 1        485994842.285226      +        806148115.372549
# 2  2.757028328841915e+136      +  1.7800309435763887e+97
# 3      27237.358068137004      +       280302.5841960784
# 4       52.87293439580913      +       625.8890879803922
# 5       21.12456488651565      +       683.1746265098039
# 6       1.357834024294688      +       55.94979809803922
# 7      27.124162374407387      +        1310.51661372549
# 8        20.8887576158872      +        740.677429117647
# 9       525.4785091057754      -       34084.34786666667
#
#                     p12.1  p12.2
# 0                     STD  +/-/=
# 1      111990354.57105155      +
# 2  1.2546798636868856e+98      +
# 3      19843.866786594663      -
# 4       62.37573744114078      +
# 5       30.86833770693369      -
# 6      3.1904317238923814      +
# 7      125.94095197761244      +
# 8       44.71930959322298      +
# 9       4922.301660150041      +
#
# [10 rows x 34 columns]

# %% [markdown]
# ## Counting superior performances

# %%
data_wilcoxon = pd.read_csv('formatted_wilcoxon_results_control_p10_5.csv')
print(data_wilcoxon.head())

results = {}
comparison_columns = [col for col in data_wilcoxon.columns if col.endswith('.2')]

for col in comparison_columns:
    paper = col.split('.')[0]
    results[paper] = 0

for index, row in data_wilcoxon.iterrows():
    for col in comparison_columns:
        paper = col.split('.')[0]
        symbol = row[col]
        if symbol == '-':
            results[paper] += 1

print("Number of times each paper was better than the control (p10):")
for paper, count in results.items():
    print(f"{paper}: {count}")
# Out:
#   Unnamed: 0                       p1                    p1.1   p1.2  \
# 0        NaN                        F                     STD  +/-/=
# 1         f1        1783023725.490196       188294652.4389397      +
# 2         f2  1.1869966430353943e+127  8.226162113489821e+127      +
# 3         f3       387294.54901960783       28669.14211175611      +
# 4         f4        679.8294901960784       33.74102871577753      +
#
#                        p2                    p2.1   p2.2                  p3  \
# 0                       F                     STD  +/-/=                   F
# 1       1038731755.882353       109278082.0239586      +   980734.9411764706
# 2  7.713740516748991e+104  4.963667671903422e+105      +  20934.992156862747
# 3      351748.54098039225      28470.423714832403      -   38703.51960784314
# 4        476.231531372549      27.324845158923505      +   12227358.43137255
#
#                  p3.1   p3.2  ...   p9.2                     p10  \
# 0                 STD  +/-/=  ...  +/-/=                       F
# 1  381626.24716945714      =  ...      +      12314.021568627451
# 2   764.5479453394661      =  ...      +  1.0666666666718795e+51
# 3   5538.719077443016      =  ...      +                362000.0
# 4  3666662.9661295256      =  ...      +      229.05882352941177
#
#                    p10.1  p10.2                     p11  \
# 0                    STD  +/-/=                       F
# 1     13177.815081316705      =       4175805401.960784
# 2  7.542472332655772e+51      =  4.133850314986474e+135
# 3      46909.59181150022      =       381450.1798039216
# 4     36.581047147131024      =      1014.5092711764704
#
#                     p11.1  p11.2                     p12  \
# 0                     STD  +/-/=                       F
# 1        485994842.285226      +        806148115.372549
# 2  2.757028328841915e+136      +  1.7800309435763887e+97
# 3      27237.358068137004      +       280302.5841960784
# 4       52.87293439580913      +       625.8890879803922
#
#                     p12.1  p12.2
# 0                     STD  +/-/=
# 1      111990354.57105155      +
# 2  1.2546798636868856e+98      +
# 3      19843.866786594663      -
# 4       62.37573744114078      +
#
# [5 rows x 34 columns]
# Number of times each paper was better than the control (p10):
# p1: 1
# p2: 4
# p3: 0
# p4: 0
# p5: 3
# p7: 2
# p8: 0
# p9: 7
# p10: 0
# p11: 1
# p12: 5

# %% [markdown]
# ## Wilcoxon Summary

# %%
import pandas as pd
from scipy.stats import wilcoxon

data = pd.read_csv('Dim 100_5.csv')

control = 'p10'
algorithms = [col for col in data.columns[1:13] if col != control]

results_list = []

for alg in algorithms:
    data_control = data[control].dropna().astype(float)
    data_alg = data[alg].dropna().astype(float)
    
    if len(data_control) > 0 and len(data_alg) > 0:
        stat, p_value = wilcoxon(data_control, data_alg, alternative='two-sided')
        better_count = sum(data_alg > data_control)
        worse_count = sum(data_alg < data_control)
        equal_count = sum(data_alg == data_control)
        
        l_value = '+' if better_count > worse_count else '-' if worse_count > better_count else '='
        
        results_list.append({
            'Proposed algorithm': alg,
            'R+': better_count,
            'R-': worse_count,
            'R=': equal_count,
            'P-value': f"{p_value:.2E}" if p_value is not None else "N/A",
            'L-value': l_value
        })

results = pd.DataFrame(results_list)


results.to_csv('wilcoxon_summary_results_control_p10_5.csv', index=False)

results
# Out:
#   Proposed algorithm  R+  R-  R=   P-value L-value
# 0                 p1  29   1   0  3.15E-07       +
# 1                 p2  26   4   0  2.69E-05       +
# 2                 p3  13  17   0  7.92E-01       -
# 3                 p4   8  22   0  4.77E-01       -
# 4                 p5  27   3   0  7.99E-06       +
# 5                 p7  28   2   0  1.40E-05       +
# 6                 p8  30   0   0  1.86E-09       +
# 7                 p9  23   7   0  1.11E-04       +
# 8                p11  29   1   0  2.05E-07       +
# 9                p12  25   5   0  1.11E-04       +

# %% [markdown]
# # Dim 100_06

# %%
import pandas as pd
from scipy.stats import wilcoxon

means = pd.read_csv('Dim 100_6.csv', index_col=0)
stds = pd.read_csv('Dim 100_std_6.csv', index_col=0)

functions = means.index.tolist()
papers = means.columns.tolist()

reference_paper = 'p10'

if reference_paper not in papers:
    papers.append(reference_paper)

formatted_results = pd.DataFrame(index=functions, columns=pd.MultiIndex.from_product([papers, ['F', 'STD', '+/-/=']]))

for function in functions:
    formatted_results.loc[function, (reference_paper, 'F')] = means.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, 'STD')] = stds.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, '+/-/=')] = '='  # Indicate no comparison

for paper in papers:
    if paper == reference_paper:
        continue  # Skip comparison logic for p10
    for function in functions:
        data_ref = means.loc[function, reference_paper]
        data_comp = means.loc[function, paper]
        std_ref = stds.loc[function, reference_paper]
        std_comp = stds.loc[function, paper]

        try:
            stat, p_value = wilcoxon(means.loc[:, reference_paper].dropna(), means.loc[:, paper].dropna(), alternative='two-sided')
            if p_value <= 0.05:
                symbol = '-' if data_ref > data_comp else '+'
            else:
                symbol = '='
        except Exception as e:
            symbol = 'Err'
            print(f"Error: {e}")

        formatted_results.loc[function, (paper, 'F')] = data_comp
        formatted_results.loc[function, (paper, 'STD')] = std_comp
        formatted_results.loc[function, (paper, '+/-/=')] = symbol

formatted_results.to_csv('formatted_wilcoxon_results_control_p10_6.csv')
print(formatted_results.head())
# Out:
#                                                    p1  \
#                                                     F
# f1                                      3379226.27451
# f2  1863316938075065573776015333922749732564071375...
# f3                                       36357.590196
# f4                                         266.145235
# f5                                          835.65098
#
#                                                              \
#                                                   STD +/-/=
# f1                                      590041.647108     +
# f2  1122594004724374393241893128749482155704899886...     +
# f3                                        9040.654684     -
# f4                                          16.129264     +
# f5                                          20.570258     +
#
#                                                    p2  \
#                                                     F
# f1                                     1914533.290196
# f2  9308796667960296113254401507097343847340722802...
# f3                                       22977.572333
# f4                                         257.289288
# f5                                         787.588956
#
#                                                                          p3  \
#                                                   STD +/-/=               F
# f1                                      315209.421266     +     5002.394576
# f2  6485968094664278166358131344546063980250752946...     +    18339.660784
# f3                                        5547.905384     -     5938.895098
# f4                                          22.328261     +  3162021.372549
# f5                                          19.409905     +      2842.28649
#
#                                                                  p4  ...  \
#                STD +/-/=                                          F  ...
# f1     3793.892696     =                                        0.0  ...
# f2      757.975926     =  450165611834180381974762873959584104448.0  ...
# f3      928.844235     =                              486370.713149  ...
# f4  1209615.002718     =                                  206.06101  ...
# f5     2226.114444     =                                  39.505724  ...
#
#       p9                   p10                               \
#    +/-/=                     F                    STD +/-/=
# f1     +          12295.882353           13156.874542     =
# f2     +  2031749130613.667969  12111874042428.644531     =
# f3     +         239450.980392           34261.573814     =
# f4     +            206.362745              42.165272     =
# f5     -            667.509804              91.076002     =
#
#                                                   p11  \
#                                                     F
# f1                                     7984492.952941
# f2  1854661547063754500410841264728451477061105201...
# f3                                       74996.562275
# f4                                         264.399607
# f5                                         852.752125
#
#                                                              \
#                                                   STD +/-/=
# f1                                      672828.858551     +
# f2  9444031105428977186861506986361257738843107327...     +
# f3                                       29939.349425     -
# f4                                          17.058893     +
# f5                                          21.438278     +
#
#                                                   p12  \
#                                                     F
# f1                                   150236051.111765
# f2  1625882292041917993417087192156979214175319649...
# f3                                      240238.017667
# f4                                         411.737343
# f5                                         564.283237
#
#
#                                                   STD +/-/=
# f1                                    26974185.795277     +
# f2  9323296693597168935419460011766105838759163389...     +
# f3                                       17388.351124     +
# f4                                           43.92004     +
# f5                                          23.831749     -
#
# [5 rows x 33 columns]

# %%
wilcoxon_results = pd.read_csv('formatted_wilcoxon_results_control_p10_6.csv')

wilcoxon_results.head(10)
# Out:
#   Unnamed: 0                      p1                    p1.1   p1.2  \
# 0        NaN                       F                     STD  +/-/=
# 1         f1       3379226.274509804       590041.6471075705      +
# 2         f2  1.8633169380750656e+96  1.1225940047243744e+97      +
# 3         f3       36357.59019607843       9040.654683960103      -
# 4         f4       266.1452352941176       16.12926431054866      +
# 5         f5       835.6509803921568      20.570257963523225      +
# 6         f6       2.679253921568627       0.217774984294848      -
# 7         f7       952.3540196078432       17.36828744816163      +
# 8         f8       838.8073921568626      17.365548143286503      +
# 9         f9      54.727474509803926       14.13483153442605      -
#
#                       p2                   p2.1   p2.2                  p3  \
# 0                      F                    STD  +/-/=                   F
# 1     1914533.2901960784      315209.4212664419      +   5002.394576470588
# 2  9.308796667960296e+63  6.485968094664278e+64      +  18339.660784313728
# 3     22977.572333333334      5547.905384168882      -   5938.895098039215
# 4     257.28928803921565       22.3282609724438      +    3162021.37254902
# 5      787.5889560784315      19.40990459614895      +  2842.2864901960784
# 6      0.838605414117647     0.0865726877115963      -    170241.031372549
# 7       894.093408627451      19.25508287602371      +  1557.1177647058826
# 8      786.4954050980393      19.71857265230168      +   3271.012156862745
# 9     6.3983443529411765     1.6153064108738042      -   2212.810588235294
#
#                  p3.1   p3.2  ...   p9.2                 p10  \
# 0                 STD  +/-/=  ...  +/-/=                   F
# 1  3793.8926958346656      =  ...      +  12295.882352941177
# 2   757.9759264836822      =  ...      +   2031749130613.668
# 3   928.8442350711932      =  ...      +  239450.98039215687
# 4  1209615.0027178386      =  ...      +  206.36274509803923
# 5   2226.114444292499      =  ...      -   667.5098039215686
# 6    45035.7906794641      =  ...      +    15.3178431372549
# 7  1094.5286686847303      =  ...      -   847.2745098039215
# 8   300.2088781545258      =  ...      -   657.7450980392157
# 9   230.1141354607962      =  ...      +   6030.313725490196
#
#                 p10.1  p10.2                     p11                  p11.1  \
# 0                 STD  +/-/=                       F                    STD
# 1   13156.87454207735      =       7984492.952941176      672828.8585513934
# 2  12111874042428.645      =  1.8546615470637545e+89  9.444031105428977e+89
# 3  34261.573814045696      =       74996.56227450981     29939.349424888533
# 4   42.16527221185381      =       264.3996066666667     17.058893273998784
# 5   91.07600199381416      =       852.7521252941178      21.43827755500668
# 6   4.258718537686803      =        3.91591938627451     0.2100333148674454
# 7  170.71649224020192      =       951.2863903921568      30.64866364946599
# 8  150.46566192041044      =               861.59051     19.950793284587785
# 9   6070.043913948448      =       37.61542966666667      5.283115791995338
#
#    p11.2                    p12                  p12.1  p12.2
# 0  +/-/=                      F                    STD  +/-/=
# 1      +      150236051.1117647     26974185.795276742      +
# 2      +  1.625882292041918e+75  9.323296693597169e+75      +
# 3      -      240238.0176666666     17388.351123651966      +
# 4      +      411.7373430588235      43.92003987174886      +
# 5      +       564.283237254902      23.83174879971325      -
# 6      -       47.4338317254902      2.378487767398734      +
# 7      +      962.2513070392156     104.17726254557522      +
# 8      +      626.2907131372549       34.1280889803787      -
# 9      -     21075.829670588235      1950.607466704104      +
#
# [10 rows x 34 columns]

# %% [markdown]
# ## Counting superior performances

# %%
data_wilcoxon = pd.read_csv('formatted_wilcoxon_results_control_p10_6.csv')
print(data_wilcoxon.head())

results = {}
comparison_columns = [col for col in data_wilcoxon.columns if col.endswith('.2')]

for col in comparison_columns:
    paper = col.split('.')[0]
    results[paper] = 0

for index, row in data_wilcoxon.iterrows():
    for col in comparison_columns:
        paper = col.split('.')[0]
        symbol = row[col]
        if symbol == '-':
            results[paper] += 1

print("Number of times each paper was better than the control (p10):")
for paper, count in results.items():
    print(f"{paper}: {count}")
# Out:
#   Unnamed: 0                      p1                    p1.1   p1.2  \
# 0        NaN                       F                     STD  +/-/=
# 1         f1       3379226.274509804       590041.6471075705      +
# 2         f2  1.8633169380750656e+96  1.1225940047243744e+97      +
# 3         f3       36357.59019607843       9040.654683960103      -
# 4         f4       266.1452352941176       16.12926431054866      +
#
#                       p2                   p2.1   p2.2                  p3  \
# 0                      F                    STD  +/-/=                   F
# 1     1914533.2901960784      315209.4212664419      +   5002.394576470588
# 2  9.308796667960296e+63  6.485968094664278e+64      +  18339.660784313728
# 3     22977.572333333334      5547.905384168882      -   5938.895098039215
# 4     257.28928803921565       22.3282609724438      +    3162021.37254902
#
#                  p3.1   p3.2  ...   p9.2                 p10  \
# 0                 STD  +/-/=  ...  +/-/=                   F
# 1  3793.8926958346656      =  ...      +  12295.882352941177
# 2   757.9759264836822      =  ...      +   2031749130613.668
# 3   928.8442350711932      =  ...      +  239450.98039215687
# 4  1209615.0027178386      =  ...      +  206.36274509803923
#
#                 p10.1  p10.2                     p11                  p11.1  \
# 0                 STD  +/-/=                       F                    STD
# 1   13156.87454207735      =       7984492.952941176      672828.8585513934
# 2  12111874042428.645      =  1.8546615470637545e+89  9.444031105428977e+89
# 3  34261.573814045696      =       74996.56227450981     29939.349424888533
# 4   42.16527221185381      =       264.3996066666667     17.058893273998784
#
#    p11.2                    p12                  p12.1  p12.2
# 0  +/-/=                      F                    STD  +/-/=
# 1      +      150236051.1117647     26974185.795276742      +
# 2      +  1.625882292041918e+75  9.323296693597169e+75      +
# 3      -      240238.0176666666     17388.351123651966      +
# 4      +      411.7373430588235      43.92003987174886      +
#
# [5 rows x 34 columns]
# Number of times each paper was better than the control (p10):
# p1: 6
# p2: 7
# p3: 0
# p4: 0
# p5: 5
# p7: 7
# p8: 0
# p9: 7
# p10: 0
# p11: 4
# p12: 9

# %% [markdown]
# ## Wilcoxon Summary

# %%
import pandas as pd
from scipy.stats import wilcoxon

data = pd.read_csv('Dim 100_6.csv')

control = 'p10'
algorithms = [col for col in data.columns[1:13] if col != control]

results_list = []

for alg in algorithms:
    data_control = data[control].dropna().astype(float)
    data_alg = data[alg].dropna().astype(float)
    
    if len(data_control) > 0 and len(data_alg) > 0:
        stat, p_value = wilcoxon(data_control, data_alg, alternative='two-sided')
        better_count = sum(data_alg > data_control)
        worse_count = sum(data_alg < data_control)
        equal_count = sum(data_alg == data_control)
        
        l_value = '+' if better_count > worse_count else '-' if worse_count > better_count else '='
        
        results_list.append({
            'Proposed algorithm': alg,
            'R+': better_count,
            'R-': worse_count,
            'R=': equal_count,
            'P-value': f"{p_value:.2E}" if p_value is not None else "N/A",
            'L-value': l_value
        })

results = pd.DataFrame(results_list)


results.to_csv('wilcoxon_summary_results_control_p10_6.csv', index=False)

results
# Out:
#   Proposed algorithm  R+  R-  R=   P-value L-value
# 0                 p1  24   6   0  6.64E-03       +
# 1                 p2  23   7   0  2.48E-02       +
# 2                 p3  11  19   0  3.82E-01       -
# 3                 p4   7  23   0  1.77E-01       -
# 4                 p5  25   5   0  7.98E-04       +
# 5                 p7  23   7   0  1.20E-02       +
# 6                 p8  30   0   0  1.86E-09       +
# 7                 p9  23   7   0  1.70E-04       +
# 8                p11  26   4   0  8.86E-05       +
# 9                p12  21   9   0  9.30E-03       +

# %% [markdown]
# # Dim 100_07

# %%
import pandas as pd
from scipy.stats import wilcoxon

means = pd.read_csv('Dim 100_7.csv', index_col=0)
stds = pd.read_csv('Dim 100_std_7.csv', index_col=0)

functions = means.index.tolist()
papers = means.columns.tolist()

reference_paper = 'p10'

if reference_paper not in papers:
    papers.append(reference_paper)

formatted_results = pd.DataFrame(index=functions, columns=pd.MultiIndex.from_product([papers, ['F', 'STD', '+/-/=']]))

for function in functions:
    formatted_results.loc[function, (reference_paper, 'F')] = means.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, 'STD')] = stds.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, '+/-/=')] = '='  # Indicate no comparison

for paper in papers:
    if paper == reference_paper:
        continue  # Skip comparison logic for p10
    for function in functions:
        data_ref = means.loc[function, reference_paper]
        data_comp = means.loc[function, paper]
        std_ref = stds.loc[function, reference_paper]
        std_comp = stds.loc[function, paper]

        try:
            stat, p_value = wilcoxon(means.loc[:, reference_paper].dropna(), means.loc[:, paper].dropna(), alternative='two-sided')
            if p_value <= 0.05:
                symbol = '-' if data_ref > data_comp else '+'
            else:
                symbol = '='
        except Exception as e:
            symbol = 'Err'
            print(f"Error: {e}")

        formatted_results.loc[function, (paper, 'F')] = data_comp
        formatted_results.loc[function, (paper, 'STD')] = std_comp
        formatted_results.loc[function, (paper, '+/-/=')] = symbol

formatted_results.to_csv('formatted_wilcoxon_results_control_p10_7.csv')
print(formatted_results.head())
# Out:
#                                                    p1  \
#                                                     F
# f1                                        5886.515373
# f2  4202679448401368541240984298168072901299917116...
# f3                                        2624.162353
# f4                                         229.477902
# f5                                         777.947353
#
#                                                              \
#                                                   STD +/-/=
# f1                                        3778.355977     =
# f2  2718063108566125023947577855788035167630065424...     =
# f3                                         952.538047     =
# f4                                          18.855446     =
# f5                                          19.012232     =
#
#                                                    p2  \
#                                                     F
# f1                                        5160.883801
# f2  4285581317989925293195092982427737719508473741...
# f3                                         132.069582
# f4                                         239.842948
# f5                                         532.737503
#
#                                                                          p3  \
#                                                   STD +/-/=               F
# f1                                        3263.316895     =     4892.417288
# f2  2528500996747200353810848356594380910650749196...     =    16726.280392
# f3                                          42.033365     =     1531.099216
# f4                                          22.918185     =  1564495.098039
# f5                                         218.354006     =     2807.228569
#
#                                           p4  ...    p9              p10  \
#               STD +/-/=                    F  ... +/-/=                F
# f1    3806.964445     =                  0.0  ...     +     12275.586275
# f2     716.482351     =  281569086191.803894  ...     +  15107690.196586
# f3     192.878609     =        172980.880348  ...     +    146496.078431
# f4  537639.276233     =           200.557027  ...     +       179.819608
# f5    2222.882479     =            22.704829  ...     -       649.254902
#
#                                                                           p11  \
#                  STD +/-/=                                                  F
# f1      13138.665144     =                                       12767.078822
# f2  102420060.749832     =  1076914778531794170228370011380682619951904063...
# f3      25727.584653     =                                        2967.267086
# f4         54.037387     =                                         223.171428
# f5         90.039826     =                                         825.644519
#
#                                                              \
#                                                   STD +/-/=
# f1                                        3681.343799     +
# f2  5601616842059424260395000942915649148985235441...     +
# f3                                         839.008579     -
# f4                                          16.305828     +
# f5                                          18.629848     +
#
#                                                   p12  \
#                                                     F
# f1                                    41908175.527451
# f2  1538549655523345308008696874077886504270138031...
# f3                                      209301.617157
# f4                                         343.199728
# f5                                         533.565632
#
#
#                                                   STD +/-/=
# f1                                     9000995.370989     +
# f2  7001412269888068176372094295313494377178368891...     +
# f3                                        15436.07532     +
# f4                                          43.899611     +
# f5                                          22.550344     -
#
# [5 rows x 33 columns]

# %%
wilcoxon_results = pd.read_csv('formatted_wilcoxon_results_control_p10_7.csv')

wilcoxon_results.head(10)
# Out:
#   Unnamed: 0                      p1                   p1.1   p1.2  \
# 0        NaN                       F                    STD  +/-/=
# 1         f1       5886.515372549021     3778.3559765891223      =
# 2         f2  4.2026794484013685e+64  2.718063108566125e+65      =
# 3         f3      2624.1623529411763      952.5380469588956      =
# 4         f4       229.4779019607843      18.85544629309943      =
# 5         f5       777.9473529411764     19.012231617859044      =
# 6         f6       0.151002294117647     0.0233180688546366      =
# 7         f7       898.9277254901962     17.787245163680616      =
# 8         f8       780.9917450980394      21.42039736073745      =
# 9         f9      0.2607996666666667     0.1516807402377934      =
#
#                       p2                    p2.1   p2.2                  p3  \
# 0                      F                     STD  +/-/=                   F
# 1      5160.883800588235      3263.3168945068114      =   4892.417288235294
# 2  4.285581317989925e+48  2.5285009967472004e+49      =  16726.280392156863
# 3     132.06958178431373      42.033365388351385      =  1531.0992156862744
# 4     239.84294843137252       22.91818469847209      =  1564495.0980392157
# 5      532.7375028039215      218.35400609647536      =  2807.2285686274518
# 6     0.0812889851372548      0.0224265102792023      =   50506.37450980392
# 7              833.28006        48.0256521252776      =   1165.288137254902
# 8      589.7749852941176       201.4770982570851      =   2989.534901960784
# 9     0.8810256313725491      0.5355944871951783      =    2075.68862745098
#
#                  p3.1   p3.2  ...   p9.2                 p10  \
# 0                 STD  +/-/=  ...  +/-/=                   F
# 1   3806.964445288777      =  ...      +  12275.586274509804
# 2   716.4823506767066      =  ...      +  15107690.196585895
# 3   192.8786086884208      =  ...      +  146496.07843137256
# 4   537639.2762332363      =  ...      +  179.81960784313725
# 5     2222.8824792762      =  ...      -   649.2549019607843
# 6  15994.259653423009      =  ...      +   14.08254901960784
# 7   678.8750390335072      =  ...      +   788.3529411764706
# 8   276.6733675780001      =  ...      -   637.2352941176471
# 9  227.07030992857096      =  ...      +   5772.607843137255
#
#                 p10.1  p10.2                     p11                  p11.1  \
# 0                 STD  +/-/=                       F                    STD
# 1  13138.665143706154      =      12767.078821568626        3681.3437990302
# 2    102420060.749832      =  1.0769147785317942e+56  5.601616842059424e+56
# 3   25727.58465290281      =        2967.26708627451        839.00857873004
# 4   54.03738727377208      =       223.1714276470588     16.305828082913177
# 5   90.03982629430176      =       825.6445188235293     18.629848094659728
# 6    3.85903007378048      =      0.4314246603921568     0.0308952156776593
# 7  132.97424540989084      =       914.1884611764706     20.422268759169725
# 8  146.30542700122757      =        824.018644509804      20.56524947027705
# 9   6152.925903953852      =      0.2246838419607843     0.0494103003444926
#
#    p11.2                     p12                  p12.1  p12.2
# 0  +/-/=                       F                    STD  +/-/=
# 1      +       41908175.52745098       9000995.37098862      +
# 2      +  1.5385496555233453e+66  7.001412269888068e+66      +
# 3      -      209301.61715686275     15436.075319742124      +
# 4      +      343.19972788235293      43.89961106551406      +
# 5      +       533.5656319607843     22.550343932933288      -
# 6      -      44.447874098039215     2.2235550506605435      +
# 7      +       815.3365855294118      93.15744892446835      +
# 8      +       595.6470068431373     31.448939412582156      -
# 9      -      17626.394313725486     1219.2562689554377      +
#
# [10 rows x 34 columns]

# %% [markdown]
# ## Counting superior performances

# %%
data_wilcoxon = pd.read_csv('formatted_wilcoxon_results_control_p10_7.csv')
print(data_wilcoxon.head())

results = {}
comparison_columns = [col for col in data_wilcoxon.columns if col.endswith('.2')]

for col in comparison_columns:
    paper = col.split('.')[0]
    results[paper] = 0

for index, row in data_wilcoxon.iterrows():
    for col in comparison_columns:
        paper = col.split('.')[0]
        symbol = row[col]
        if symbol == '-':
            results[paper] += 1

print("Number of times each paper was better than the control (p10):")
for paper, count in results.items():
    print(f"{paper}: {count}")
# Out:
#   Unnamed: 0                      p1                   p1.1   p1.2  \
# 0        NaN                       F                    STD  +/-/=
# 1         f1       5886.515372549021     3778.3559765891223      =
# 2         f2  4.2026794484013685e+64  2.718063108566125e+65      =
# 3         f3      2624.1623529411763      952.5380469588956      =
# 4         f4       229.4779019607843      18.85544629309943      =
#
#                       p2                    p2.1   p2.2                  p3  \
# 0                      F                     STD  +/-/=                   F
# 1      5160.883800588235      3263.3168945068114      =   4892.417288235294
# 2  4.285581317989925e+48  2.5285009967472004e+49      =  16726.280392156863
# 3     132.06958178431373      42.033365388351385      =  1531.0992156862744
# 4     239.84294843137252       22.91818469847209      =  1564495.0980392157
#
#                 p3.1   p3.2  ...   p9.2                 p10  \
# 0                STD  +/-/=  ...  +/-/=                   F
# 1  3806.964445288777      =  ...      +  12275.586274509804
# 2  716.4823506767066      =  ...      +  15107690.196585895
# 3  192.8786086884208      =  ...      +  146496.07843137256
# 4  537639.2762332363      =  ...      +  179.81960784313725
#
#                 p10.1  p10.2                     p11                  p11.1  \
# 0                 STD  +/-/=                       F                    STD
# 1  13138.665143706154      =      12767.078821568626        3681.3437990302
# 2    102420060.749832      =  1.0769147785317942e+56  5.601616842059424e+56
# 3   25727.58465290281      =        2967.26708627451        839.00857873004
# 4   54.03738727377208      =       223.1714276470588     16.305828082913177
#
#    p11.2                     p12                  p12.1  p12.2
# 0  +/-/=                       F                    STD  +/-/=
# 1      +       41908175.52745098       9000995.37098862      +
# 2      +  1.5385496555233453e+66  7.001412269888068e+66      +
# 3      -      209301.61715686275     15436.075319742124      +
# 4      +      343.19972788235293      43.89961106551406      +
#
# [5 rows x 34 columns]
# Number of times each paper was better than the control (p10):
# p1: 0
# p2: 0
# p3: 0
# p4: 0
# p5: 0
# p7: 0
# p8: 10
# p9: 6
# p10: 0
# p11: 7
# p12: 10

# %% [markdown]
# ## Wilcoxon Summary

# %%
import pandas as pd
from scipy.stats import wilcoxon

data = pd.read_csv('Dim 100_7.csv')

control = 'p10'
algorithms = [col for col in data.columns[1:13] if col != control]

results_list = []

for alg in algorithms:
    data_control = data[control].dropna().astype(float)
    data_alg = data[alg].dropna().astype(float)
    
    if len(data_control) > 0 and len(data_alg) > 0:
        stat, p_value = wilcoxon(data_control, data_alg, alternative='two-sided')
        better_count = sum(data_alg > data_control)
        worse_count = sum(data_alg < data_control)
        equal_count = sum(data_alg == data_control)
        
        l_value = '+' if better_count > worse_count else '-' if worse_count > better_count else '='
        
        results_list.append({
            'Proposed algorithm': alg,
            'R+': better_count,
            'R-': worse_count,
            'R=': equal_count,
            'P-value': f"{p_value:.2E}" if p_value is not None else "N/A",
            'L-value': l_value
        })

results = pd.DataFrame(results_list)


results.to_csv('wilcoxon_summary_results_control_p10_7.csv', index=False)

results
# Out:
#   Proposed algorithm  R+  R-  R=   P-value L-value
# 0                 p1  19  11   0  7.77E-01       +
# 1                 p2  16  14   0  6.26E-01       +
# 2                 p3  11  19   0  3.28E-01       -
# 3                 p4   8  22   0  6.99E-02       -
# 4                 p5  19  11   0  1.77E-01       +
# 5                 p7  18  12   0  4.77E-01       +
# 6                 p8  20  10   0  2.99E-03       +
# 7                 p9  24   6   0  1.89E-04       +
# 8                p11  23   7   0  1.75E-02       +
# 9                p12  20  10   0  2.62E-02       +

# %% [markdown]
# # Dim 100_08

# %%
import pandas as pd
from scipy.stats import wilcoxon

means = pd.read_csv('Dim 100_8.csv', index_col=0)
stds = pd.read_csv('Dim 100_std_8.csv', index_col=0)

functions = means.index.tolist()
papers = means.columns.tolist()

reference_paper = 'p10'

if reference_paper not in papers:
    papers.append(reference_paper)

formatted_results = pd.DataFrame(index=functions, columns=pd.MultiIndex.from_product([papers, ['F', 'STD', '+/-/=']]))

for function in functions:
    formatted_results.loc[function, (reference_paper, 'F')] = means.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, 'STD')] = stds.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, '+/-/=')] = '='  # Indicate no comparison

for paper in papers:
    if paper == reference_paper:
        continue  # Skip comparison logic for p10
    for function in functions:
        data_ref = means.loc[function, reference_paper]
        data_comp = means.loc[function, paper]
        std_ref = stds.loc[function, reference_paper]
        std_comp = stds.loc[function, paper]

        try:
            stat, p_value = wilcoxon(means.loc[:, reference_paper].dropna(), means.loc[:, paper].dropna(), alternative='two-sided')
            if p_value <= 0.05:
                symbol = '-' if data_ref > data_comp else '+'
            else:
                symbol = '='
        except Exception as e:
            symbol = 'Err'
            print(f"Error: {e}")

        formatted_results.loc[function, (paper, 'F')] = data_comp
        formatted_results.loc[function, (paper, 'STD')] = std_comp
        formatted_results.loc[function, (paper, '+/-/=')] = symbol

formatted_results.to_csv('formatted_wilcoxon_results_control_p10_8.csv')
print(formatted_results.head())
# Out:
#                                                    p1  \
#                                                     F
# f1                                        4628.987171
# f2  25163205861439040945521779933961401566045929472.0
# f3                                         412.340922
# f4                                         220.548275
# f5                                         701.355314
#
#                                                              \
#                                                   STD +/-/=
# f1                                        3752.540651     =
# f2  1692391418339140227984235859039583972693890826...     =
# f3                                         210.056691     =
# f4                                          18.071272     =
# f5                                           19.62676     =
#
#                                                p2  \
#                                                 F
# f1                                    2158.556606
# f2  4458886169559409167017901742654965569028096.0
# f3                                       1.983508
# f4                                     239.842948
# f5                                     309.731597
#
#                                                                       p3  \
#                                                STD +/-/=               F
# f1                                     1988.767465     -     4772.372359
# f2  17135378901790863308945648151711070510120960.0     +    12909.016275
# f3                                        0.967464     -      771.133333
# f4                                       22.918185     +  1059492.529412
# f5                                      187.970396     -     2788.593294
#
#                                    p4  ...    p9           p10                \
#               STD +/-/=             F  ... +/-/=             F           STD
# f1    3647.808754     =           0.0  ...     +  12261.935294  13120.433833
# f2    1077.388545     =      0.901961  ...     +    2443.19046   16501.75793
# f3      65.913495     =  14870.546393  ...     +  86547.058824  17222.356116
# f4  329831.719976     =    195.468062  ...     +    165.391961      54.30497
# f5    2223.206853     =     21.108739  ...     -    641.039216     89.443368
#
#                                                  p11  \
#    +/-/=                                           F
# f1     =                                 4785.644786
# f2     =  2635217567227330040486949354298719338496.0
# f3     =                                  492.172354
# f4     =                                   216.01511
# f5     =                                  807.552198
#
#                                                        \
#                                             STD +/-/=
# f1                                  3007.690221     =
# f2  10458932548085667476083549007056235134976.0     =
# f3                                   206.860288     =
# f4                                    16.885822     =
# f5                                    19.290576     =
#
#                                                   p12  \
#                                                     F
# f1                                    11867705.980196
# f2  1781623786441612898392494758661798212361098412...
# f3                                      181265.829647
# f4                                         306.838306
# f5                                         524.385059
#
#
#                                                   STD +/-/=
# f1                                     3178314.246215     =
# f2  8995458282920777959922941105680836693500865236...     =
# f3                                       14423.510746     =
# f4                                          43.388447     =
# f5                                          22.632756     =
#
# [5 rows x 33 columns]

# %%
wilcoxon_results = pd.read_csv('formatted_wilcoxon_results_control_p10_8.csv')

wilcoxon_results.head(10)
# Out:
#   Unnamed: 0                     p1                    p1.1   p1.2  \
# 0        NaN                      F                     STD  +/-/=
# 1         f1      4628.987170588235       3752.540650870445      =
# 2         f2  2.516320586143904e+46  1.6923914183391402e+47      =
# 3         f3      412.3409215686274        210.056690938408      =
# 4         f4     220.54827450980395      18.071272289463696      =
# 5         f5      701.3553137254903      19.626760287723812      =
# 6         f6     0.0071365276470588      0.0032244227547533      =
# 7         f7      836.6149411764706      23.517451583803457      =
# 8         f8      700.7568039215687      21.614854919180907      =
# 9         f9      0.045954613517647      0.1137910646865998      =
#
#                       p2                    p2.1   p2.2                  p3  \
# 0                      F                     STD  +/-/=                   F
# 1     2158.5566058921568      1988.7674650208564      -   4772.372359019608
# 2  4.458886169559409e+42  1.7135378901790863e+43      +  12909.016274509806
# 3     1.9835076862745105      0.9674640396297796      -   771.1333333333332
# 4     239.84294843137252       22.91818469847209      +  1059492.5294117648
# 5      309.7315971372549      187.97039636915247      -  2788.5932941176466
# 6     0.0077699363411764      0.0052739510529798      -   5476.677450980392
# 7      445.4364756862744       209.3712420549208      -   1011.240137254902
# 8      377.8794221960785      191.36847670505543      -   2832.437647058823
# 9     0.8066850695294118      0.5219104491614162      -  1983.8317647058825
#
#                  p3.1   p3.2  ...   p9.2                 p10  \
# 0                 STD  +/-/=  ...  +/-/=                   F
# 1    3647.80875354956      =  ...      +  12261.935294117646
# 2  1077.3885450148698      =  ...      +   2443.190460162745
# 3     65.913494986088      =  ...      +   86547.05882352941
# 4  329831.71997635835      =  ...      +   165.3919607843137
# 5   2223.206852818176      =  ...      -   641.0392156862745
# 6  3514.6280748417817      =  ...      +  13.156666666666666
# 7   585.4445311880878      =  ...      +   770.8235294117648
# 8   288.2054295564818      =  ...      -   628.3333333333334
# 9  220.41832741764395      =  ...      +   5671.823529411765
#
#                 p10.1  p10.2                   p11                   p11.1  \
# 0                 STD  +/-/=                     F                     STD
# 1  13120.433833122384      =     4785.644786470588      3007.6902214003862
# 2  16501.757930378837      =  2.63521756722733e+39  1.0458932548085667e+40
# 3   17222.35611561352      =     492.1723535294119      206.86028835071613
# 4   54.30496976569791      =    216.01510960784316      16.885822401927225
# 5    89.4433681677338      =     807.5521982352941        19.2905755099524
# 6   3.744864021022354      =    0.0322241628431372       0.002679899424406
# 7  132.73808884672292      =     846.7880243137254      102.25109246021808
# 8   143.4381285852062      =     802.9478211764706       23.27337750600176
# 9   6091.677597283879      =    0.0018552106308235      0.0124079787382958
#
#    p11.2                    p12                  p12.1  p12.2
# 0  +/-/=                      F                    STD  +/-/=
# 1      =      11867705.98019608     3178314.2462150776      =
# 2      =  1.781623786441613e+60  8.995458282920778e+60      =
# 3      =     181265.82964705885     14423.510746109994      =
# 4      =     306.83830592156863     43.388446833098655      =
# 5      =      524.3850591372549      22.63275612784904      =
# 6      =      43.01575976470589     2.2583580881028227      =
# 7      =      762.1642523333334      89.03087524061536      =
# 8      =      586.4104152745098      30.69166367010269      =
# 9      =      16224.92144117647      993.6140638692368      =
#
# [10 rows x 34 columns]

# %% [markdown]
# ## Counting superior performances

# %%
data_wilcoxon = pd.read_csv('formatted_wilcoxon_results_control_p10_8.csv')
print(data_wilcoxon.head())

results = {}
comparison_columns = [col for col in data_wilcoxon.columns if col.endswith('.2')]

for col in comparison_columns:
    paper = col.split('.')[0]
    results[paper] = 0

for index, row in data_wilcoxon.iterrows():
    for col in comparison_columns:
        paper = col.split('.')[0]
        symbol = row[col]
        if symbol == '-':
            results[paper] += 1

print("Number of times each paper was better than the control (p10):")
for paper, count in results.items():
    print(f"{paper}: {count}")
# Out:
#   Unnamed: 0                     p1                    p1.1   p1.2  \
# 0        NaN                      F                     STD  +/-/=
# 1         f1      4628.987170588235       3752.540650870445      =
# 2         f2  2.516320586143904e+46  1.6923914183391402e+47      =
# 3         f3      412.3409215686274        210.056690938408      =
# 4         f4     220.54827450980395      18.071272289463696      =
#
#                       p2                    p2.1   p2.2                  p3  \
# 0                      F                     STD  +/-/=                   F
# 1     2158.5566058921568      1988.7674650208564      -   4772.372359019608
# 2  4.458886169559409e+42  1.7135378901790863e+43      +  12909.016274509806
# 3     1.9835076862745105      0.9674640396297796      -   771.1333333333332
# 4     239.84294843137252       22.91818469847209      +  1059492.5294117648
#
#                  p3.1   p3.2  ...   p9.2                 p10  \
# 0                 STD  +/-/=  ...  +/-/=                   F
# 1    3647.80875354956      =  ...      +  12261.935294117646
# 2  1077.3885450148698      =  ...      +   2443.190460162745
# 3     65.913494986088      =  ...      +   86547.05882352941
# 4  329831.71997635835      =  ...      +   165.3919607843137
#
#                 p10.1  p10.2                   p11                   p11.1  \
# 0                 STD  +/-/=                     F                     STD
# 1  13120.433833122384      =     4785.644786470588      3007.6902214003862
# 2  16501.757930378837      =  2.63521756722733e+39  1.0458932548085667e+40
# 3   17222.35611561352      =     492.1723535294119      206.86028835071613
# 4   54.30496976569791      =    216.01510960784316      16.885822401927225
#
#    p11.2                    p12                  p12.1  p12.2
# 0  +/-/=                      F                    STD  +/-/=
# 1      =      11867705.98019608     3178314.2462150776      =
# 2      =  1.781623786441613e+60  8.995458282920778e+60      =
# 3      =     181265.82964705885     14423.510746109994      =
# 4      =     306.83830592156863     43.388446833098655      =
#
# [5 rows x 34 columns]
# Number of times each paper was better than the control (p10):
# p1: 0
# p2: 22
# p3: 0
# p4: 26
# p5: 0
# p7: 0
# p8: 12
# p9: 6
# p10: 0
# p11: 0
# p12: 0

# %% [markdown]
# ## Wilcoxon Summary

# %%
import pandas as pd
from scipy.stats import wilcoxon

data = pd.read_csv('Dim 100_8.csv')

control = 'p10'
algorithms = [col for col in data.columns[1:13] if col != control]

results_list = []

for alg in algorithms:
    data_control = data[control].dropna().astype(float)
    data_alg = data[alg].dropna().astype(float)
    
    if len(data_control) > 0 and len(data_alg) > 0:
        stat, p_value = wilcoxon(data_control, data_alg, alternative='two-sided')
        better_count = sum(data_alg > data_control)
        worse_count = sum(data_alg < data_control)
        equal_count = sum(data_alg == data_control)
        
        l_value = '+' if better_count > worse_count else '-' if worse_count > better_count else '='
        
        results_list.append({
            'Proposed algorithm': alg,
            'R+': better_count,
            'R-': worse_count,
            'R=': equal_count,
            'P-value': f"{p_value:.2E}" if p_value is not None else "N/A",
            'L-value': l_value
        })

results = pd.DataFrame(results_list)


results.to_csv('wilcoxon_summary_results_control_p10_8.csv', index=False)

results
# Out:
#   Proposed algorithm  R+  R-  R=   P-value L-value
# 0                 p1  15  15   0  4.77E-01       =
# 1                 p2   8  22   0  8.71E-03       -
# 2                 p3  12  18   0  5.29E-01       -
# 3                 p4   4  26   0  2.32E-04       -
# 4                 p5  10  20   0  5.49E-02       -
# 5                 p7   9  21   0  2.37E-01       -
# 6                 p8  18  12   0  2.62E-02       +
# 7                 p9  24   6   0  2.56E-04       +
# 8                p11  20  10   0  3.28E-01       +
# 9                p12  18  12   0  8.41E-02       +

# %% [markdown]
# # Dim 100_09

# %%
import pandas as pd
from scipy.stats import wilcoxon

means = pd.read_csv('Dim 100_9.csv', index_col=0)
stds = pd.read_csv('Dim 100_std_9.csv', index_col=0)

functions = means.index.tolist()
papers = means.columns.tolist()

reference_paper = 'p10'

if reference_paper not in papers:
    papers.append(reference_paper)

formatted_results = pd.DataFrame(index=functions, columns=pd.MultiIndex.from_product([papers, ['F', 'STD', '+/-/=']]))

for function in functions:
    formatted_results.loc[function, (reference_paper, 'F')] = means.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, 'STD')] = stds.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, '+/-/=')] = '='  # Indicate no comparison

for paper in papers:
    if paper == reference_paper:
        continue  # Skip comparison logic for p10
    for function in functions:
        data_ref = means.loc[function, reference_paper]
        data_comp = means.loc[function, paper]
        std_ref = stds.loc[function, reference_paper]
        std_comp = stds.loc[function, paper]

        try:
            stat, p_value = wilcoxon(means.loc[:, reference_paper].dropna(), means.loc[:, paper].dropna(), alternative='two-sided')
            if p_value <= 0.05:
                symbol = '-' if data_ref > data_comp else '+'
            else:
                symbol = '='
        except Exception as e:
            symbol = 'Err'
            print(f"Error: {e}")

        formatted_results.loc[function, (paper, 'F')] = data_comp
        formatted_results.loc[function, (paper, 'STD')] = std_comp
        formatted_results.loc[function, (paper, '+/-/=')] = symbol

formatted_results.to_csv('formatted_wilcoxon_results_control_p10_9.csv')
print(formatted_results.head())
# Out:
#                                    p1                                      \
#                                     F                                 STD
# f1                         391.899182                          244.146792
# f2  6811267347926494558871468638208.0  44873540818041603202812418719744.0
# f3                          52.001206                           37.376325
# f4                         211.343412                           13.656056
# f5                         652.445863                           21.316621
#
#                                                p2  \
#    +/-/=                                        F
# f1     =                               219.725497
# f2     =  5403908494515717152558960549484822528.0
# f3     =                                  0.14087
# f4     =                               239.842948
# f5     =                               148.290909
#
#                                                                p3  \
#                                          STD +/-/=              F
# f1                                785.719931     -    1708.238528
# f2  17744378846979321151077242771595067392.0     +    11736.61098
# f3                                  0.113594     -     575.163118
# f4                                 22.918185     +  733073.745098
# f5                                142.699929     -    2647.566392
#
#                                  p4  ...    p9           p10                \
#               STD +/-/=           F  ... +/-/=             F           STD
# f1    2044.169091     =         0.0  ...     +  12244.621569  13099.786875
# f2     878.268493     =         0.0  ...     +      0.000317       0.00053
# f3      62.564153     =    14.21192  ...     +  51592.156863  12089.873305
# f4  272521.628884     =  192.295089  ...     +    146.107906     58.747047
# f5    2113.189101     =   21.108739  ...     -    636.215686     88.372055
#
#                                          p11  \
#    +/-/=                                   F
# f1     =                         4524.462684
# f2     =  30813824192328848037564829925376.0
# f3     =                            125.6934
# f4     =                          211.826003
# f5     =                           338.55974
#
#                                                \
#                                     STD +/-/=
# f1                          2859.926182     =
# f2  203077761845568399027950869020672.0     =
# f3                            71.000372     =
# f4                            15.941833     =
# f5                            84.169538     =
#
#                                                   p12  \
#                                                     F
# f1                                     3578246.603333
# f2  1856926542916617455918944684199127634572087408...
# f3                                      156634.371745
# f4                                         284.409905
# f5                                         521.480806
#
#
#                                                   STD +/-/=
# f1                                      962554.199627     =
# f2  5916232321044224421975699543953039633668236354...     =
# f3                                       13291.508321     =
# f4                                          41.402237     =
# f5                                          22.795137     =
#
# [5 rows x 33 columns]

# %%
wilcoxon_results = pd.read_csv('formatted_wilcoxon_results_control_p10_9.csv')

wilcoxon_results.head(10)
# Out:
#   Unnamed: 0                     p1                  p1.1   p1.2  \
# 0        NaN                      F                   STD  +/-/=
# 1         f1      391.8991823529412    244.14679222055355      =
# 2         f2  6.811267347926495e+30  4.48735408180416e+31      =
# 3         f3      52.00120647058822      37.3763252367898      =
# 4         f4     211.34341176470588    13.656056006548129      =
# 5         f5      652.4458627450981    21.316621053488387      =
# 6         f6     0.0002777761372549    0.0006862835052377      =
# 7         f7      787.2183333333332    19.504795252195425      =
# 8         f8      649.8920980392157    17.389329666358336      =
# 9         f9     0.0459039568627451    0.1137956282776918      =
#
#                       p2                   p2.1   p2.2                  p3  \
# 0                      F                    STD  +/-/=                   F
# 1     219.72549707627448      785.7199309585579      -  1708.2385276470588
# 2  5.403908494515717e+36  1.774437884697932e+37      +  11736.610980392154
# 3     0.1408703034705882     0.1135942944404482      -   575.1631176470588
# 4     239.84294843137252      22.91818469847209      +   733073.7450980392
# 5     148.29090913725489     142.69992859433592      -  2647.5663921568625
# 6     0.0030806666894117     0.0030505942760765      -  1587.0910784313728
# 7      192.4711529411765     115.82169378335348      -   779.8105098039216
# 8      122.8642955490196      86.44394077074791      -   2603.186862745098
# 9     0.8059394555294116     0.5214073665794842      -   1863.610980392157
#
#                  p3.1   p3.2  ...   p9.2                 p10  \
# 0                 STD  +/-/=  ...  +/-/=                   F
# 1  2044.1690910095256      =  ...      +   12244.62156862745
# 2    878.268493248148      =  ...      +  0.0003166047058823
# 3   62.56415267975088      =  ...      +    51592.1568627451
# 4  272521.62888409593      =  ...      +  146.10790588235295
# 5   2113.189101264953      =  ...      -   636.2156862745098
# 6    1445.14771589389      =  ...      +   12.26529411764706
# 7   531.3245439283245      =  ...      +   757.4117647058823
# 8  270.78361240485066      =  ...      -   625.3333333333334
# 9   209.6282147905996      =  ...      +  5541.6274509803925
#
#                 p10.1  p10.2                    p11                  p11.1  \
# 0                 STD  +/-/=                      F                    STD
# 1  13099.786875340327      =      4524.462683921569     2859.9261818943637
# 2  0.0005299184879322      =  3.081382419232885e+31  2.030777618455684e+32
# 3   12089.87330472961      =     125.69340007843137      71.00037170593625
# 4   58.74704700039344      =     211.82600294117648     15.941833477838316
# 5   88.37205523296183      =      338.5597401960785      84.16953820072219
# 6   3.619951983725088      =     0.0016723665784313     0.0001706951217148
# 7  116.50703529554086      =     487.29790725490193     200.68521126052423
# 8  142.30107087173246      =      366.7399433333334     110.77776869063818
# 9   5913.653938169101      =     0.0017554717617894     0.0124129468948022
#
#    p11.2                     p12                  p12.1  p12.2
# 0  +/-/=                       F                    STD  +/-/=
# 1      =       3578246.603333333      962554.1996273332      =
# 2      =  1.8569265429166175e+55  5.916232321044224e+55      =
# 3      =      156634.37174509803     13291.508320727386      =
# 4      =      284.40990511764704      41.40223748636237      =
# 5      =       521.4808062941177      22.79513686771195      =
# 6      =        42.2084118235294     2.3667910318942083      =
# 7      =       745.8192690588236      88.46240209876284      =
# 8      =       583.5534719019607      30.38404490228777      =
# 9      =      15564.878937254902      895.7638277582238      =
#
# [10 rows x 34 columns]

# %% [markdown]
# ## Counting superior performances

# %%
data_wilcoxon = pd.read_csv('formatted_wilcoxon_results_control_p10_9.csv')
print(data_wilcoxon.head())

results = {}
comparison_columns = [col for col in data_wilcoxon.columns if col.endswith('.2')]

for col in comparison_columns:
    paper = col.split('.')[0]
    results[paper] = 0

for index, row in data_wilcoxon.iterrows():
    for col in comparison_columns:
        paper = col.split('.')[0]
        symbol = row[col]
        if symbol == '-':
            results[paper] += 1

print("Number of times each paper was better than the control (p10):")
for paper, count in results.items():
    print(f"{paper}: {count}")
# Out:
#   Unnamed: 0                     p1                  p1.1   p1.2  \
# 0        NaN                      F                   STD  +/-/=
# 1         f1      391.8991823529412    244.14679222055355      =
# 2         f2  6.811267347926495e+30  4.48735408180416e+31      =
# 3         f3      52.00120647058822      37.3763252367898      =
# 4         f4     211.34341176470588    13.656056006548129      =
#
#                       p2                   p2.1   p2.2                  p3  \
# 0                      F                    STD  +/-/=                   F
# 1     219.72549707627448      785.7199309585579      -  1708.2385276470588
# 2  5.403908494515717e+36  1.774437884697932e+37      +  11736.610980392154
# 3     0.1408703034705882     0.1135942944404482      -   575.1631176470588
# 4     239.84294843137252      22.91818469847209      +   733073.7450980392
#
#                  p3.1   p3.2  ...   p9.2                 p10  \
# 0                 STD  +/-/=  ...  +/-/=                   F
# 1  2044.1690910095256      =  ...      +   12244.62156862745
# 2    878.268493248148      =  ...      +  0.0003166047058823
# 3   62.56415267975088      =  ...      +    51592.1568627451
# 4  272521.62888409593      =  ...      +  146.10790588235295
#
#                 p10.1  p10.2                    p11                  p11.1  \
# 0                 STD  +/-/=                      F                    STD
# 1  13099.786875340327      =      4524.462683921569     2859.9261818943637
# 2  0.0005299184879322      =  3.081382419232885e+31  2.030777618455684e+32
# 3   12089.87330472961      =     125.69340007843137      71.00037170593625
# 4   58.74704700039344      =     211.82600294117648     15.941833477838316
#
#    p11.2                     p12                  p12.1  p12.2
# 0  +/-/=                       F                    STD  +/-/=
# 1      =       3578246.603333333      962554.1996273332      =
# 2      =  1.8569265429166175e+55  5.916232321044224e+55      =
# 3      =      156634.37174509803     13291.508320727386      =
# 4      =      284.40990511764704      41.40223748636237      =
#
# [5 rows x 34 columns]
# Number of times each paper was better than the control (p10):
# p1: 0
# p2: 25
# p3: 0
# p4: 26
# p5: 24
# p7: 24
# p8: 12
# p9: 6
# p10: 0
# p11: 0
# p12: 0

# %% [markdown]
# ## Wilcoxon Summary

# %%
import pandas as pd
from scipy.stats import wilcoxon

data = pd.read_csv('Dim 100_9.csv')

control = 'p10'
algorithms = [col for col in data.columns[1:13] if col != control]

results_list = []

for alg in algorithms:
    data_control = data[control].dropna().astype(float)
    data_alg = data[alg].dropna().astype(float)
    
    if len(data_control) > 0 and len(data_alg) > 0:
        stat, p_value = wilcoxon(data_control, data_alg, alternative='two-sided')
        better_count = sum(data_alg > data_control)
        worse_count = sum(data_alg < data_control)
        equal_count = sum(data_alg == data_control)
        
        l_value = '+' if better_count > worse_count else '-' if worse_count > better_count else '='
        
        results_list.append({
            'Proposed algorithm': alg,
            'R+': better_count,
            'R-': worse_count,
            'R=': equal_count,
            'P-value': f"{p_value:.2E}" if p_value is not None else "N/A",
            'L-value': l_value
        })

results = pd.DataFrame(results_list)


results.to_csv('wilcoxon_summary_results_control_p10_9.csv', index=False)

results
# Out:
#   Proposed algorithm  R+  R-  R=   P-value L-value
# 0                 p1  14  16   0  2.45E-01       -
# 1                 p2   5  25   0  7.30E-04       -
# 2                 p3  12  18   0  3.39E-01       -
# 3                 p4   4  26   0  1.70E-04       -
# 4                 p5   6  24   0  5.05E-04       -
# 5                 p7   6  24   0  6.64E-03       -
# 6                 p8  18  12   0  3.10E-02       +
# 7                 p9  24   6   0  2.56E-04       +
# 8                p11  10  20   0  5.23E-02       -
# 9                p12  18  12   0  1.24E-01       +

# %% [markdown]
# # Dim 100_10

# %%
import pandas as pd
from scipy.stats import wilcoxon

means = pd.read_csv('Dim 100_10.csv', index_col=0)
stds = pd.read_csv('Dim 100_std_10.csv', index_col=0)

functions = means.index.tolist()
papers = means.columns.tolist()

reference_paper = 'p10'

if reference_paper not in papers:
    papers.append(reference_paper)

formatted_results = pd.DataFrame(index=functions, columns=pd.MultiIndex.from_product([papers, ['F', 'STD', '+/-/=']]))

for function in functions:
    formatted_results.loc[function, (reference_paper, 'F')] = means.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, 'STD')] = stds.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, '+/-/=')] = '='  # Indicate no comparison

for paper in papers:
    if paper == reference_paper:
        continue  # Skip comparison logic for p10
    for function in functions:
        data_ref = means.loc[function, reference_paper]
        data_comp = means.loc[function, paper]
        std_ref = stds.loc[function, reference_paper]
        std_comp = stds.loc[function, paper]

        try:
            stat, p_value = wilcoxon(means.loc[:, reference_paper].dropna(), means.loc[:, paper].dropna(), alternative='two-sided')
            if p_value <= 0.05:
                symbol = '-' if data_ref > data_comp else '+'
            else:
                symbol = '='
        except Exception as e:
            symbol = 'Err'
            print(f"Error: {e}")

        formatted_results.loc[function, (paper, 'F')] = data_comp
        formatted_results.loc[function, (paper, 'STD')] = std_comp
        formatted_results.loc[function, (paper, '+/-/=')] = symbol

formatted_results.to_csv('formatted_wilcoxon_results_control_p10_10.csv')
print(formatted_results.head())
# Out:
#                             p1                                     \
#                              F                          STD +/-/=
# f1                    0.240956                       0.1818     -
# f2  178227364971044271030272.0  1252278495975846484901888.0     +
# f3                     3.38786                     2.750804     -
# f4                  204.105569                     11.99097     +
# f5                  604.475863                    18.710839     -
#
#                                     p2                                       \
#                                      F                                  STD
# f1                            0.007812                             0.016396
# f2  57403113192492753011970592997376.0  267647353937230566891091304382464.0
# f3                            0.000451                             0.001838
# f4                          162.612477                            81.176685
# f5                           35.865454                            13.264449
#
#                      p3                              p4  ...    p9  \
#    +/-/=              F            STD +/-/=          F  ... +/-/=
# f1     -     520.610504     580.071974     =        0.0  ...     +
# f2     +   11663.729412     878.394403     =        0.0  ...     +
# f3     -     483.031863      50.900326     =        0.0  ...     +
# f4     +  578970.058824  236140.275475     =  185.53431  ...     +
# f5     -    2639.472745     2113.32379     =  17.841642  ...     -
#
#              p10                                               p11  \
#                F           STD +/-/=                             F
# f1  12223.539216  13079.068375     =                     87.993633
# f2      0.000211      0.000109     =  58992008211575095303340032.0
# f3  29131.372549   8342.578954     =                     19.016622
# f4     125.36338     67.425235     =                    207.381081
# f5    632.333333     88.974918     =                    118.629147
#
#                                          \
#                               STD +/-/=
# f1                      64.648799     -
# f2  228865014246871199272402944.0     +
# f3                      11.416697     -
# f4                       12.63096     +
# f5                      70.349704     -
#
#                                                   p12  \
#                                                     F
# f1                                     1093902.847157
# f2  7200762162968723893089642589830137232107283180...
# f3                                      133751.445451
# f4                                         268.914769
# f5                                         520.555351
#
#
#                                                   STD +/-/=
# f1                                      366205.990003     =
# f2  2932792853646689006192453961911307871800814250...     =
# f3                                       11956.701086     =
# f4                                          40.269778     =
# f5                                          22.813502     =
#
# [5 rows x 33 columns]

# %%
wilcoxon_results = pd.read_csv('formatted_wilcoxon_results_control_p10_10.csv')

wilcoxon_results.head(10)
# Out:
#   Unnamed: 0                      p1                    p1.1   p1.2  \
# 0        NaN                       F                     STD  +/-/=
# 1         f1               0.2409559       0.181800179596639      -
# 2         f2  1.7822736497104427e+23  1.2522784959758465e+24      +
# 3         f3       3.387859549019608      2.7508038187109456      -
# 4         f4        204.105568627451      11.990970268113436      +
# 5         f5        604.475862745098      18.710838758847576      -
# 6         f6      0.0002065238643137        0.00061808638173      -
# 7         f7       740.1311372549019       20.67324822558969      -
# 8         f8       600.1003137254902       20.73991750081933      -
# 9         f9      0.0459039568627451      0.1137956282776918      -
#
#                       p2                    p2.1   p2.2                  p3  \
# 0                      F                     STD  +/-/=                   F
# 1     0.0078120173308627      0.0163959326842541      -   520.6105035882352
# 2  5.740311319249275e+31  2.6764735393723057e+32      +  11663.729411764703
# 3     0.0004505862786274      0.0018383342204097      -  483.03186274509807
# 4      162.6124771352941       81.17668489951109      +   578970.0588235294
# 5              35.865454      13.264449379501707      -   2639.472745098039
# 6     0.0023002619242156      0.0026384322831065      -   1374.588843137255
# 7     122.51330352941176       6.513314412705119      -   728.6812941176471
# 8      34.29564721568628       10.95678817821178      -   2506.986078431373
# 9     0.8059393317647059       0.521407288842001      -  1818.3233333333335
#
#                  p3.1   p3.2  ...   p9.2                 p10  \
# 0                 STD  +/-/=  ...  +/-/=                   F
# 1   580.0719738637962      =  ...      +  12223.539215686274
# 2   878.3944026135363      =  ...      +  0.0002113692156862
# 3   50.90032555927304      =  ...      +   29131.37254901961
# 4   236140.2754746251      =  ...      +  125.36338039215688
# 5  2113.3237899426585      =  ...      -   632.3333333333334
# 6  1273.9146563333652      =  ...      +  11.542941176470586
# 7   508.2658297680609      =  ...      +   741.4705882352941
# 8   288.9006125600333      =  ...      -   622.4705882352941
# 9   204.1426027979564      =  ...      +   5367.705882352941
#
#                 p10.1  p10.2                     p11                  p11.1  \
# 0                 STD  +/-/=                       F                    STD
# 1  13079.068374585766      =        87.9936333137255        64.648798973824
# 2   0.000109463255234      =  5.8992008211575095e+25  2.288650142468712e+26
# 3    8342.57895415472      =      19.016622401960785     11.416696682996406
# 4   67.42523521791951      =       207.3810809803921     12.630960392675076
# 5   88.97491752012147      =      118.62914670588236       70.3497040017532
# 6   3.287776705192501      =   4.944631517647059e-05  9.489287379499324e-06
# 7    113.503105760596      =      277.94737078431376     199.14961121766183
# 8   142.2733288966708      =      146.73540494117643     110.75430315761024
# 9    5714.01293448445      =      0.0017554558823529     0.0124129475848557
#
#    p11.2                    p12                  p12.1  p12.2
# 0  +/-/=                      F                    STD  +/-/=
# 1      -      1093902.847156863       366205.990002818      =
# 2      +  7.200762162968724e+51  2.932792853646689e+52      =
# 3      -      133751.4454509804     11956.701086468936      =
# 4      +       268.914769254902       40.2697779114881      =
# 5      -      520.5553506274509       22.8135015366472      =
# 6      -      41.68758764705883     2.4356512310902247      =
# 7      -      740.7190444313726       88.2317245194701      =
# 8      -      582.7033250196077     30.366250120070514      =
# 9      -     15219.184564705882      859.4620839800949      =
#
# [10 rows x 34 columns]

# %% [markdown]
# ## Counting superior performances

# %%
data_wilcoxon = pd.read_csv('formatted_wilcoxon_results_control_p10_10.csv')
print(data_wilcoxon.head())

results = {}
comparison_columns = [col for col in data_wilcoxon.columns if col.endswith('.2')]

for col in comparison_columns:
    paper = col.split('.')[0]
    results[paper] = 0

for index, row in data_wilcoxon.iterrows():
    for col in comparison_columns:
        paper = col.split('.')[0]
        symbol = row[col]
        if symbol == '-':
            results[paper] += 1

print("Number of times each paper was better than the control (p10):")
for paper, count in results.items():
    print(f"{paper}: {count}")
# Out:
#   Unnamed: 0                      p1                    p1.1   p1.2  \
# 0        NaN                       F                     STD  +/-/=
# 1         f1               0.2409559       0.181800179596639      -
# 2         f2  1.7822736497104427e+23  1.2522784959758465e+24      +
# 3         f3       3.387859549019608      2.7508038187109456      -
# 4         f4        204.105568627451      11.990970268113436      +
#
#                       p2                    p2.1   p2.2                  p3  \
# 0                      F                     STD  +/-/=                   F
# 1     0.0078120173308627      0.0163959326842541      -   520.6105035882352
# 2  5.740311319249275e+31  2.6764735393723057e+32      +  11663.729411764703
# 3     0.0004505862786274      0.0018383342204097      -  483.03186274509807
# 4      162.6124771352941       81.17668489951109      +   578970.0588235294
#
#                 p3.1   p3.2  ...   p9.2                 p10  \
# 0                STD  +/-/=  ...  +/-/=                   F
# 1  580.0719738637962      =  ...      +  12223.539215686274
# 2  878.3944026135363      =  ...      +  0.0002113692156862
# 3  50.90032555927304      =  ...      +   29131.37254901961
# 4  236140.2754746251      =  ...      +  125.36338039215688
#
#                 p10.1  p10.2                     p11                  p11.1  \
# 0                 STD  +/-/=                       F                    STD
# 1  13079.068374585766      =        87.9936333137255        64.648798973824
# 2   0.000109463255234      =  5.8992008211575095e+25  2.288650142468712e+26
# 3    8342.57895415472      =      19.016622401960785     11.416696682996406
# 4   67.42523521791951      =       207.3810809803921     12.630960392675076
#
#    p11.2                    p12                  p12.1  p12.2
# 0  +/-/=                      F                    STD  +/-/=
# 1      -      1093902.847156863       366205.990002818      =
# 2      +  7.200762162968724e+51  2.932792853646689e+52      =
# 3      -      133751.4454509804     11956.701086468936      =
# 4      +       268.914769254902       40.2697779114881      =
#
# [5 rows x 34 columns]
# Number of times each paper was better than the control (p10):
# p1: 21
# p2: 28
# p3: 0
# p4: 26
# p5: 27
# p7: 26
# p8: 0
# p9: 6
# p10: 0
# p11: 22
# p12: 0

# %% [markdown]
# ## Wilcoxon Summary

# %%
import pandas as pd
from scipy.stats import wilcoxon

data = pd.read_csv('Dim 100_10.csv')

control = 'p10'
algorithms = [col for col in data.columns[1:13] if col != control]

results_list = []

for alg in algorithms:
    data_control = data[control].dropna().astype(float)
    data_alg = data[alg].dropna().astype(float)
    
    if len(data_control) > 0 and len(data_alg) > 0:
        stat, p_value = wilcoxon(data_control, data_alg, alternative='two-sided')
        better_count = sum(data_alg > data_control)
        worse_count = sum(data_alg < data_control)
        equal_count = sum(data_alg == data_control)
        
        l_value = '+' if better_count > worse_count else '-' if worse_count > better_count else '='
        
        results_list.append({
            'Proposed algorithm': alg,
            'R+': better_count,
            'R-': worse_count,
            'R=': equal_count,
            'P-value': f"{p_value:.2E}" if p_value is not None else "N/A",
            'L-value': l_value
        })

results = pd.DataFrame(results_list)


results.to_csv('wilcoxon_summary_results_control_p10_10.csv', index=False)

results
# Out:
#   Proposed algorithm  R+  R-  R=   P-value L-value
# 0                 p1   9  21   0  4.73E-02       -
# 1                 p2   2  28   0  6.92E-06       -
# 2                 p3  11  19   0  2.80E-01       -
# 3                 p4   4  26   0  1.37E-04       -
# 4                 p5   3  27   0  1.40E-05       -
# 5                 p7   4  26   0  3.45E-05       -
# 6                 p8  18  12   0  5.49E-02       +
# 7                 p9  24   6   0  2.56E-04       +
# 8                p11   8  22   0  7.11E-03       -
# 9                p12  18  12   0  1.35E-01       +

# %% [markdown]
# # Dim 100_11

# %%
import pandas as pd
from scipy.stats import wilcoxon

means = pd.read_csv('Dim 100_11.csv', index_col=0)
stds = pd.read_csv('Dim 100_std_11.csv', index_col=0)

functions = means.index.tolist()
papers = means.columns.tolist()

reference_paper = 'p10'

if reference_paper not in papers:
    papers.append(reference_paper)

formatted_results = pd.DataFrame(index=functions, columns=pd.MultiIndex.from_product([papers, ['F', 'STD', '+/-/=']]))

for function in functions:
    formatted_results.loc[function, (reference_paper, 'F')] = means.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, 'STD')] = stds.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, '+/-/=')] = '='  # Indicate no comparison

for paper in papers:
    if paper == reference_paper:
        continue  # Skip comparison logic for p10
    for function in functions:
        data_ref = means.loc[function, reference_paper]
        data_comp = means.loc[function, paper]
        std_ref = stds.loc[function, reference_paper]
        std_comp = stds.loc[function, paper]

        try:
            stat, p_value = wilcoxon(means.loc[:, reference_paper].dropna(), means.loc[:, paper].dropna(), alternative='two-sided')
            if p_value <= 0.05:
                symbol = '-' if data_ref > data_comp else '+'
            else:
                symbol = '='
        except Exception as e:
            symbol = 'Err'
            print(f"Error: {e}")

        formatted_results.loc[function, (paper, 'F')] = data_comp
        formatted_results.loc[function, (paper, 'STD')] = std_comp
        formatted_results.loc[function, (paper, '+/-/=')] = symbol

formatted_results.to_csv('formatted_wilcoxon_results_control_p10_11.csv')
print(formatted_results.head())
# Out:
#                      p1                             \
#                       F                  STD +/-/=
# f1             0.000232             0.000239     -
# f2  13306027197784032.0  88699580361265808.0     +
# f3             0.180428             0.156533     -
# f4           202.076392            11.727545     +
# f5           511.731647             21.97578     -
#
#                                 p2                                         \
#                                  F                              STD +/-/=
# f1                        0.000001                         0.000004     -
# f2  8223563405107569316016947200.0  56985235306744322072948768768.0     +
# f3                         0.00013                         0.000878     -
# f4                      162.612477                        81.176685     +
# f5                       35.829173                        13.217991     -
#
#                p3                               p4  ...    p9           p10  \
#                 F            STD +/-/=           F  ... +/-/=             F
# f1      197.14645      220.07822     =         0.0  ...     +  12202.460784
# f2   11608.960588     882.938027     =         0.0  ...     +      0.000178
# f3     433.191471      49.152036     =         0.0  ...     +  15685.882353
# f4  429438.862745  170128.348106     =  174.407444  ...     +    112.804418
# f5    2632.743392    2113.294992     =   13.442758  ...     -    629.196078
#
#                                                p11  \
#              STD +/-/=                           F
# f1  13053.473915     =                    0.343229
# f2      0.000085     =  358678362495478981984256.0
# f3   5154.417932     =                      2.0067
# f4     68.820469     =                  204.118196
# f5     88.567913     =                  104.110212
#
#                                        \
#                             STD +/-/=
# f1                     0.214917     -
# f2  1742428011074394932641792.0     +
# f3                     1.484592     -
# f4                    10.152165     +
# f5                    37.335145     -
#
#                                                   p12  \
#                                                     F
# f1                                      313223.432824
# f2  1412873426573275841543681256010967028934310363...
# f3                                      115575.010335
# f4                                         257.855653
# f5                                         520.259415
#
#
#                                                   STD +/-/=
# f1                                       94207.618776     =
# f2  4293614736875355646203273000485371182222223081...     =
# f3                                       10215.763158     =
# f4                                          37.511846     =
# f5                                          22.826901     =
#
# [5 rows x 33 columns]

# %%
wilcoxon_results = pd.read_csv('formatted_wilcoxon_results_control_p10_11.csv')

wilcoxon_results.head(10)
# Out:
#   Unnamed: 0                      p1                   p1.1   p1.2  \
# 0        NaN                       F                    STD  +/-/=
# 1         f1      0.0002322044321568     0.0002389838895401      -
# 2         f2  1.3306027197784032e+16  8.869958036126581e+16      +
# 3         f3      0.1804284764705882     0.1565333928859616      -
# 4         f4       202.0763921568627     11.727544844574547      +
# 5         f5       511.7316470588236      21.97577994227989      -
# 6         f6      0.0002055025288235     0.0006170502148321      -
# 7         f7       654.8164705882351     30.580194993769712      -
# 8         f8      509.44129411764703     20.211533333663937      -
# 9         f9      0.0459039568627451     0.1137956282776918      -
#
#                        p2                   p2.1   p2.2                  p3  \
# 0                       F                    STD  +/-/=                   F
# 1  1.3866582405098045e-06   4.01704945345606e-06      -  197.14645043137256
# 2   8.223563405107569e+27  5.698523530674432e+28      +  11608.960588235292
# 3      0.0001296539357705     0.0008779700885149      -   433.1914705882352
# 4       162.6124771352941      81.17668489951109      +    429438.862745098
# 5       35.82917274509804     13.217991463096064      -  2632.7433921568627
# 6      0.0022275195790631     0.0025814677204007      -  1156.7554509803922
# 7      122.51330352941176      6.513314412705119      -   693.8486274509804
# 8       34.29564721568628      10.95678817821178      -  2363.4421568627454
# 9      0.8059393317647059      0.521407288842001      -  1674.7821568627448
#
#                  p3.1   p3.2  ...   p9.2                 p10  \
# 0                 STD  +/-/=  ...  +/-/=                   F
# 1    220.078220267839      =  ...      +  12202.460784313726
# 2   882.9380273378544      =  ...      +  0.0001775182352941
# 3  49.152036227484594      =  ...      +  15685.882352941177
# 4  170128.34810628506      =  ...      +  112.80441764705884
# 5   2113.294991936359      =  ...      -   629.1960784313726
# 6  1130.4998143197688      =  ...      +  10.854705882352937
# 7   505.1008089820409      =  ...      +    731.843137254902
# 8  305.71590771283275      =  ...      -   615.7450980392157
# 9  214.86396687219064      =  ...      +   5319.019607843137
#
#                    p10.1  p10.2                   p11                  p11.1  \
# 0                    STD  +/-/=                     F                    STD
# 1     13053.473915129716      =    0.3432288742745097     0.2149166513966867
# 2  8.508641419873997e-05      =  3.58678362495479e+23  1.742428011074395e+24
# 3      5154.417932361838      =    2.0066997770588237     1.4845921211197624
# 4      68.82046881374899      =    204.11819607843145     10.152165481700724
# 5      88.56791337013054      =     104.1102120980392     37.335145107638006
# 6       3.05391060961745      =  1.86173056745098e-05  6.950259820292047e-06
# 7     108.76172419091728      =     204.5110392156863     131.14394437792117
# 8     143.30932445577565      =    118.78271296078432      51.37900813987964
# 9      5721.952057869475      =    0.0017554558823529     0.0124129475848557
#
#    p11.2                     p12                   p12.1  p12.2
# 0  +/-/=                       F                     STD  +/-/=
# 1      -       313223.4328235294         94207.618775513      =
# 2      +  1.4128734265732758e+49  4.2936147368753556e+49      =
# 3      -      115575.01033529412      10215.763157969091      =
# 4      +       257.8556534509804       37.51184602107179      =
# 5      -       520.2594150784314       22.82690093201017      =
# 6      -      41.199680764705874       2.442385301416016      =
# 7      -       739.0874650784316       88.11146692340888      =
# 8      -        582.438245745098       30.35670525699048      =
# 9      -      15032.834262745098       833.1375044705438      =
#
# [10 rows x 34 columns]

# %% [markdown]
# ## Counting superior performances

# %%
data_wilcoxon = pd.read_csv('formatted_wilcoxon_results_control_p10_11.csv')
print(data_wilcoxon.head())

results = {}
comparison_columns = [col for col in data_wilcoxon.columns if col.endswith('.2')]

for col in comparison_columns:
    paper = col.split('.')[0]
    results[paper] = 0

for index, row in data_wilcoxon.iterrows():
    for col in comparison_columns:
        paper = col.split('.')[0]
        symbol = row[col]
        if symbol == '-':
            results[paper] += 1

print("Number of times each paper was better than the control (p10):")
for paper, count in results.items():
    print(f"{paper}: {count}")
# Out:
#   Unnamed: 0                      p1                   p1.1   p1.2  \
# 0        NaN                       F                    STD  +/-/=
# 1         f1      0.0002322044321568     0.0002389838895401      -
# 2         f2  1.3306027197784032e+16  8.869958036126581e+16      +
# 3         f3      0.1804284764705882     0.1565333928859616      -
# 4         f4       202.0763921568627     11.727544844574547      +
#
#                        p2                   p2.1   p2.2                  p3  \
# 0                       F                    STD  +/-/=                   F
# 1  1.3866582405098045e-06   4.01704945345606e-06      -  197.14645043137256
# 2   8.223563405107569e+27  5.698523530674432e+28      +  11608.960588235292
# 3      0.0001296539357705     0.0008779700885149      -   433.1914705882352
# 4       162.6124771352941      81.17668489951109      +    429438.862745098
#
#                  p3.1   p3.2  ...   p9.2                 p10  \
# 0                 STD  +/-/=  ...  +/-/=                   F
# 1    220.078220267839      =  ...      +  12202.460784313726
# 2   882.9380273378544      =  ...      +  0.0001775182352941
# 3  49.152036227484594      =  ...      +  15685.882352941177
# 4  170128.34810628506      =  ...      +  112.80441764705884
#
#                    p10.1  p10.2                   p11                  p11.1  \
# 0                    STD  +/-/=                     F                    STD
# 1     13053.473915129716      =    0.3432288742745097     0.2149166513966867
# 2  8.508641419873997e-05      =  3.58678362495479e+23  1.742428011074395e+24
# 3      5154.417932361838      =    2.0066997770588237     1.4845921211197624
# 4      68.82046881374899      =    204.11819607843145     10.152165481700724
#
#    p11.2                     p12                   p12.1  p12.2
# 0  +/-/=                       F                     STD  +/-/=
# 1      -       313223.4328235294         94207.618775513      =
# 2      +  1.4128734265732758e+49  4.2936147368753556e+49      =
# 3      -      115575.01033529412      10215.763157969091      =
# 4      +       257.8556534509804       37.51184602107179      =
#
# [5 rows x 34 columns]
# Number of times each paper was better than the control (p10):
# p1: 23
# p2: 28
# p3: 0
# p4: 26
# p5: 27
# p7: 27
# p8: 0
# p9: 6
# p10: 0
# p11: 24
# p12: 0

# %% [markdown]
# ## Wilcoxon Summary

# %%
import pandas as pd
from scipy.stats import wilcoxon

data = pd.read_csv('Dim 100_11.csv')

control = 'p10'
algorithms = [col for col in data.columns[1:13] if col != control]

results_list = []

for alg in algorithms:
    data_control = data[control].dropna().astype(float)
    data_alg = data[alg].dropna().astype(float)
    
    if len(data_control) > 0 and len(data_alg) > 0:
        stat, p_value = wilcoxon(data_control, data_alg, alternative='two-sided')
        better_count = sum(data_alg > data_control)
        worse_count = sum(data_alg < data_control)
        equal_count = sum(data_alg == data_control)
        
        l_value = '+' if better_count > worse_count else '-' if worse_count > better_count else '='
        
        results_list.append({
            'Proposed algorithm': alg,
            'R+': better_count,
            'R-': worse_count,
            'R=': equal_count,
            'P-value': f"{p_value:.2E}" if p_value is not None else "N/A",
            'L-value': l_value
        })

results = pd.DataFrame(results_list)


results.to_csv('wilcoxon_summary_results_control_p10_11.csv', index=False)

results
# Out:
#   Proposed algorithm  R+  R-  R=   P-value L-value
# 0                 p1   7  23   0  9.93E-03       -
# 1                 p2   2  28   0  6.92E-06       -
# 2                 p3  11  19   0  2.71E-01       -
# 3                 p4   4  26   0  1.23E-04       -
# 4                 p5   3  27   0  9.22E-06       -
# 5                 p7   3  27   0  1.40E-05       -
# 6                 p8  16  14   0  1.29E-01       +
# 7                 p9  24   6   0  3.13E-04       +
# 8                p11   6  24   0  1.34E-03       -
# 9                p12  19  11   0  1.35E-01       +

# %% [markdown]
# # Dim 100_12

# %%
import pandas as pd
from scipy.stats import wilcoxon

means = pd.read_csv('Dim 100_12.csv', index_col=0)
stds = pd.read_csv('Dim 100_std_12.csv', index_col=0)

functions = means.index.tolist()
papers = means.columns.tolist()

reference_paper = 'p10'

if reference_paper not in papers:
    papers.append(reference_paper)

formatted_results = pd.DataFrame(index=functions, columns=pd.MultiIndex.from_product([papers, ['F', 'STD', '+/-/=']]))

for function in functions:
    formatted_results.loc[function, (reference_paper, 'F')] = means.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, 'STD')] = stds.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, '+/-/=')] = '='  # Indicate no comparison

for paper in papers:
    if paper == reference_paper:
        continue  # Skip comparison logic for p10
    for function in functions:
        data_ref = means.loc[function, reference_paper]
        data_comp = means.loc[function, paper]
        std_ref = stds.loc[function, reference_paper]
        std_comp = stds.loc[function, paper]

        try:
            stat, p_value = wilcoxon(means.loc[:, reference_paper].dropna(), means.loc[:, paper].dropna(), alternative='two-sided')
            if p_value <= 0.05:
                symbol = '-' if data_ref > data_comp else '+'
            else:
                symbol = '='
        except Exception as e:
            symbol = 'Err'
            print(f"Error: {e}")

        formatted_results.loc[function, (paper, 'F')] = data_comp
        formatted_results.loc[function, (paper, 'STD')] = std_comp
        formatted_results.loc[function, (paper, '+/-/=')] = symbol

formatted_results.to_csv('formatted_wilcoxon_results_control_p10_12.csv')
print(formatted_results.head())
# Out:
#                    p1                                                     p2  \
#                     F                 STD +/-/=                            F
# f1                0.0                 0.0     -                          0.0
# f2  2619278162.332479  16868636662.298426     +  2700830198275530620403712.0
# f3           0.007289            0.007381     -                     0.000114
# f4         198.080667           13.459741     +                   162.612477
# f5         347.718176           20.088848     -                    35.436256
#
#                                                   p3                       \
#                              STD +/-/=             F            STD +/-/=
# f1                           0.0     -     79.061241      83.499268     =
# f2  18762118434802888387592192.0     +  11601.134314     886.499833     =
# f3                      0.000777     -    405.381275      46.461164     =
# f4                     81.176685     +  300222.55098  124126.404018     =
# f5                     13.031623     -   2627.314784    2113.641127     =
#
#             p4  ...    p9           p10                      \
#              F  ... +/-/=             F           STD +/-/=
# f1         0.0  ...     +  12192.378431  13040.350495     =
# f2         0.0  ...     +      0.000152      0.000077     =
# f3         0.0  ...     +   8244.117647   3189.297161     =
# f4  164.884612  ...     +     99.581875      70.12739     =
# f5   12.449431  ...     -    626.568627     87.108509     =
#
#                        p11                                 \
#                          F                      STD +/-/=
# f1                0.000077                 0.000079     -
# f2  45363885466701684736.0  194836803973108006912.0     +
# f3                0.001832                 0.012612     -
# f4              193.386603                30.595504     +
# f5               28.658721                 5.224187     -
#
#                                                   p12  \
#                                                     F
# f1                                       91579.679849
# f2  90918279697571194581015880501497792012486705152.0
# f3                                       98331.651335
# f4                                         250.626126
# f5                                         520.166055
#
#
#                                                   STD +/-/=
# f1                                       30659.629096     =
# f2  1808378829083043442387360865751649199309497303...     =
# f3                                        8821.788543     =
# f4                                          35.200677     =
# f5                                          22.830893     =
#
# [5 rows x 33 columns]

# %%
wilcoxon_results = pd.read_csv('formatted_wilcoxon_results_control_p10_12.csv')

wilcoxon_results.head(10)
# Out:
#   Unnamed: 0                      p1                   p1.1   p1.2  \
# 0        NaN                       F                    STD  +/-/=
# 1         f1  2.2903917058823534e-07  2.315908856193241e-07      -
# 2         f2      2619278162.3324785     16868636662.298426      +
# 3         f3      0.0072888735490196     0.0073810974866601      -
# 4         f4      198.08066666666664     13.459740714611677      +
# 5         f5       347.7181764705882      20.08884754959375      -
# 6         f6      0.0002028472021568     0.0006139806852366      -
# 7         f7       488.6698039215685      21.59603975316717      -
# 8         f8      353.34968627450985      15.38065823636717      -
# 9         f9      0.0459039568627451     0.1137956282776918      -
#
#                        p2                    p2.1   p2.2                  p3  \
# 0                       F                     STD  +/-/=                   F
# 1    8.23328156862745e-10   4.341037517147269e-09      -   79.06124149411764
# 2  2.7008301982755306e+24  1.8762118434802888e+25      +   11601.13431372549
# 3       0.000114131642549      0.0007773368543819      -   405.3812745098039
# 4       162.6124771352941       81.17668489951109      +  300222.55098039214
# 5       35.43625607843137       13.03162347194542      -  2627.3147843137253
# 6      0.0022185517841766      0.0025761596805223      -  1095.7026078431372
# 7      122.51330352941176       6.513314412705119      -   656.0479999999999
# 8       34.29564721568628       10.95678817821178      -   2097.833725490196
# 9      0.8059393317647059       0.521407288842001      -  1632.5471372549025
#
#                  p3.1   p3.2  ...   p9.2                 p10  \
# 0                 STD  +/-/=  ...  +/-/=                   F
# 1   83.49926796454034      =  ...      +   12192.37843137255
# 2   886.4998332553615      =  ...      +  0.0001515849019607
# 3  46.461164232151965      =  ...      +   8244.117647058823
# 4  124126.40401848174      =  ...      +   99.58187450980392
# 5   2113.641127268161      =  ...      -   626.5686274509804
# 6   1129.540050541345      =  ...      +  10.352352941176472
# 7  496.32638088155295      =  ...      +   725.5098039215686
# 8   323.5924755054848      =  ...      -   614.5686274509804
# 9   238.2155249438526      =  ...      +   5239.411764705882
#
#                    p10.1  p10.2                     p11  \
# 0                    STD  +/-/=                       F
# 1      13040.35049491842      =   7.694259200392156e-05
# 2  7.744972832197186e-05      =  4.5363885466701685e+19
# 3      3189.297160553722      =      0.0018316514922156
# 4      70.12739033530572      =       193.3866025490196
# 5      87.10850905104795      =      28.658721352941186
# 6      2.946969588880324      =  1.7801967590196077e-05
# 7     105.03918457432916      =      122.19394274509804
# 8     144.43700776408238      =       29.67318862745098
# 9      5616.041335445299      =      0.0017554558823529
#
#                    p11.1  p11.2                    p12  \
# 0                    STD  +/-/=                      F
# 1   7.92981755444922e-05      -      91579.67984901962
# 2   1.94836803973108e+20      +  9.091827969757119e+46
# 3     0.0126118763335065      -      98331.65133529413
# 4     30.595504294470643      +     250.62612568627452
# 5       5.22418732501046      -      520.1660554705882
# 6  6.970057898636953e-06      -      40.77312643137255
# 7      4.422605028948294      -      738.6033696666666
# 8      7.402988417715064      -      582.3581779215687
# 9     0.0124129475848557      -     14913.352729411768
#
#                     p12.1  p12.2
# 0                     STD  +/-/=
# 1      30659.629095516622      =
# 2  1.8083788290830434e+47      =
# 3       8821.788543218048      =
# 4       35.20067732783102      =
# 5       22.83089326717523      =
# 6       2.386389261878044      =
# 7       88.09189950543528      =
# 8       30.35408137745313      =
# 9       813.0874786134088      =
#
# [10 rows x 34 columns]

# %% [markdown]
# ## Counting superior performances

# %%
data_wilcoxon = pd.read_csv('formatted_wilcoxon_results_control_p10_12.csv')
print(data_wilcoxon.head())

results = {}
comparison_columns = [col for col in data_wilcoxon.columns if col.endswith('.2')]

for col in comparison_columns:
    paper = col.split('.')[0]
    results[paper] = 0

for index, row in data_wilcoxon.iterrows():
    for col in comparison_columns:
        paper = col.split('.')[0]
        symbol = row[col]
        if symbol == '-':
            results[paper] += 1

print("Number of times each paper was better than the control (p10):")
for paper, count in results.items():
    print(f"{paper}: {count}")
# Out:
#   Unnamed: 0                      p1                   p1.1   p1.2  \
# 0        NaN                       F                    STD  +/-/=
# 1         f1  2.2903917058823534e-07  2.315908856193241e-07      -
# 2         f2      2619278162.3324785     16868636662.298426      +
# 3         f3      0.0072888735490196     0.0073810974866601      -
# 4         f4      198.08066666666664     13.459740714611677      +
#
#                        p2                    p2.1   p2.2                  p3  \
# 0                       F                     STD  +/-/=                   F
# 1    8.23328156862745e-10   4.341037517147269e-09      -   79.06124149411764
# 2  2.7008301982755306e+24  1.8762118434802888e+25      +   11601.13431372549
# 3       0.000114131642549      0.0007773368543819      -   405.3812745098039
# 4       162.6124771352941       81.17668489951109      +  300222.55098039214
#
#                  p3.1   p3.2  ...   p9.2                 p10  \
# 0                 STD  +/-/=  ...  +/-/=                   F
# 1   83.49926796454034      =  ...      +   12192.37843137255
# 2   886.4998332553615      =  ...      +  0.0001515849019607
# 3  46.461164232151965      =  ...      +   8244.117647058823
# 4  124126.40401848174      =  ...      +   99.58187450980392
#
#                    p10.1  p10.2                     p11                 p11.1  \
# 0                    STD  +/-/=                       F                   STD
# 1      13040.35049491842      =   7.694259200392156e-05  7.92981755444922e-05
# 2  7.744972832197186e-05      =  4.5363885466701685e+19  1.94836803973108e+20
# 3      3189.297160553722      =      0.0018316514922156    0.0126118763335065
# 4      70.12739033530572      =       193.3866025490196    30.595504294470643
#
#    p11.2                    p12                   p12.1  p12.2
# 0  +/-/=                      F                     STD  +/-/=
# 1      -      91579.67984901962      30659.629095516622      =
# 2      +  9.091827969757119e+46  1.8083788290830434e+47      =
# 3      -      98331.65133529413       8821.788543218048      =
# 4      +     250.62612568627452       35.20067732783102      =
#
# [5 rows x 34 columns]
# Number of times each paper was better than the control (p10):
# p1: 24
# p2: 27
# p3: 0
# p4: 26
# p5: 27
# p7: 27
# p8: 0
# p9: 6
# p10: 0
# p11: 28
# p12: 0

# %% [markdown]
# ## Wilcoxon Summary

# %%
import pandas as pd
from scipy.stats import wilcoxon

data = pd.read_csv('Dim 100_12.csv')

control = 'p10'
algorithms = [col for col in data.columns[1:13] if col != control]

results_list = []

for alg in algorithms:
    data_control = data[control].dropna().astype(float)
    data_alg = data[alg].dropna().astype(float)
    
    if len(data_control) > 0 and len(data_alg) > 0:
        stat, p_value = wilcoxon(data_control, data_alg, alternative='two-sided')
        better_count = sum(data_alg > data_control)
        worse_count = sum(data_alg < data_control)
        equal_count = sum(data_alg == data_control)
        
        l_value = '+' if better_count > worse_count else '-' if worse_count > better_count else '='
        
        results_list.append({
            'Proposed algorithm': alg,
            'R+': better_count,
            'R-': worse_count,
            'R=': equal_count,
            'P-value': f"{p_value:.2E}" if p_value is not None else "N/A",
            'L-value': l_value
        })

results = pd.DataFrame(results_list)


results.to_csv('wilcoxon_summary_results_control_p10_12.csv', index=False)

results
# Out:
#   Proposed algorithm  R+  R-  R=   P-value L-value
# 0                 p1   6  24   0  2.19E-03       -
# 1                 p2   3  27   0  7.99E-06       -
# 2                 p3  11  19   0  2.71E-01       -
# 3                 p4   4  26   0  7.91E-05       -
# 4                 p5   3  27   0  7.99E-06       -
# 5                 p7   3  27   0  1.22E-05       -
# 6                 p8  16  14   0  1.40E-01       +
# 7                 p9  24   6   0  3.13E-04       +
# 8                p11   2  28   0  6.92E-06       -
# 9                p12  19  11   0  1.35E-01       +

# %% [markdown]
# # Dim 100_13

# %%
import pandas as pd
from scipy.stats import wilcoxon

means = pd.read_csv('Dim 100_13.csv', index_col=0)
stds = pd.read_csv('Dim 100_std_13.csv', index_col=0)

functions = means.index.tolist()
papers = means.columns.tolist()

reference_paper = 'p10'

if reference_paper not in papers:
    papers.append(reference_paper)

formatted_results = pd.DataFrame(index=functions, columns=pd.MultiIndex.from_product([papers, ['F', 'STD', '+/-/=']]))

for function in functions:
    formatted_results.loc[function, (reference_paper, 'F')] = means.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, 'STD')] = stds.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, '+/-/=')] = '='  # Indicate no comparison

for paper in papers:
    if paper == reference_paper:
        continue  # Skip comparison logic for p10
    for function in functions:
        data_ref = means.loc[function, reference_paper]
        data_comp = means.loc[function, paper]
        std_ref = stds.loc[function, reference_paper]
        std_comp = stds.loc[function, paper]

        try:
            stat, p_value = wilcoxon(means.loc[:, reference_paper].dropna(), means.loc[:, paper].dropna(), alternative='two-sided')
            if p_value <= 0.05:
                symbol = '-' if data_ref > data_comp else '+'
            else:
                symbol = '='
        except Exception as e:
            symbol = 'Err'
            print(f"Error: {e}")

        formatted_results.loc[function, (paper, 'F')] = data_comp
        formatted_results.loc[function, (paper, 'STD')] = std_comp
        formatted_results.loc[function, (paper, '+/-/=')] = symbol

formatted_results.to_csv('formatted_wilcoxon_results_control_p10_13.csv')
print(formatted_results.head())
# Out:
#               p1                                         p2  \
#                F            STD +/-/=                     F
# f1           0.0            0.0     -                   0.0
# f2  53097.168787  246760.103748     +  175537155186502848.0
# f3      0.000177       0.000188     -              0.000113
# f4    192.935441      20.213163     +            162.612477
# f5     215.86302      11.282776     -             35.436256
#
#                                            p3                       \
#                      STD +/-/=              F            STD +/-/=
# f1                   0.0     -      32.575548       34.87542     =
# f2  880076429914016640.0     +    11599.67902     886.878645     =
# f3              0.000773     -     367.391294       43.45846     =
# f4             81.176685     +  262412.827451  112478.995318     =
# f5             13.031623     -    2622.884353    2113.859367     =
#
#             p4  ...    p9           p10                      \
#              F  ... +/-/=             F           STD +/-/=
# f1         0.0  ...     +  12173.633333  13016.732617     =
# f2         0.0  ...     +      0.000136      0.000071     =
# f3         0.0  ...     +   3941.176471   1719.364505     =
# f4  160.077927  ...     +     90.739947     70.282751     =
# f5   11.655315  ...     -    625.352941     87.275274     =
#
#                      p11                               \
#                        F                    STD +/-/=
# f1                   0.0                    0.0     -
# f2  164743313505833920.0  1081046347628128384.0     +
# f3              0.000135                0.00093     -
# f4            193.386603              30.595504     +
# f5             28.658721               5.224187     -
#
#                                                  p12  \
#                                                    F
# f1                                      29894.953529
# f2  2364587698301607371129639159895098338318483456.0
# f3                                      84329.102463
# f4                                        244.469255
# f5                                        520.138345
#
#
#                                                  STD +/-/=
# f1                                      10302.991724     =
# f2  4525833470544033201496065987224348268515295232.0     =
# f3                                       7564.002996     =
# f4                                         31.924492     =
# f5                                         22.832295     =
#
# [5 rows x 33 columns]

# %%
wilcoxon_results = pd.read_csv('formatted_wilcoxon_results_control_p10_13.csv')

wilcoxon_results.head(10)
# Out:
#   Unnamed: 0                      p1                    p1.1   p1.2  \
# 0        NaN                       F                     STD  +/-/=
# 1         f1  2.2701176470588234e-10  1.6052155823265436e-09      -
# 2         f2       53097.16878693419      246760.10374764717      +
# 3         f3      0.0001773273333333        0.00018813044377      -
# 4         f4       192.9354411764706      20.213162505093656      +
# 5         f5       215.8630196078431       11.28277584828985      -
# 6         f6      0.0002024438986274      0.0006137873655891      -
# 7         f7       351.2239607843137      13.050153964925707      -
# 8         f8       213.4750784313726      14.547756508988902      -
# 9         f9      0.0459039568627451      0.1137956282776918      -
#
#                        p2                   p2.1   p2.2                  p3  \
# 0                       F                    STD  +/-/=                   F
# 1                     0.0                    0.0      -   32.57554795098039
# 2  1.7553715518650285e+17  8.800764299140166e+17      +  11599.679019607842
# 3      0.0001128210645686     0.0007727962943159      -    367.391294117647
# 4       162.6124771352941      81.17668489951109      +   262412.8274509804
# 5       35.43625607843137      13.03162347194542      -  2622.8843529411765
# 6      0.0022178770922082     0.0025761345258255      -  1094.3099803921568
# 7      122.51330352941176      6.513314412705119      -   549.0560980392157
# 8       34.29564721568628      10.95678817821178      -   2073.631176470588
# 9      0.8059393317647059      0.521407288842001      -   1624.583705882353
#
#                  p3.1   p3.2  ...   p9.2                 p10  \
# 0                 STD  +/-/=  ...  +/-/=                   F
# 1   34.87542012384564      =  ...      +  12173.633333333337
# 2   886.8786449827788      =  ...      +  0.0001361798039215
# 3   43.45846034254858      =  ...      +   3941.176470588235
# 4   112478.9953176271      =  ...      +   90.73994705882356
# 5   2113.859366529445      =  ...      -   625.3529411764706
# 6  1129.4851323718426      =  ...      +                9.84
# 7   494.9472820681781      =  ...      +   718.6078431372549
# 8   325.0019250117775      =  ...      -   610.1764705882352
# 9  238.63578040154556      =  ...      +   5201.764705882353
#
#                    p10.1  p10.2                     p11  \
# 0                    STD  +/-/=                       F
# 1     13016.732617487516      =   6.593327656862745e-08
# 2  7.077482161384343e-05      =  1.6474331350583392e+17
# 3      1719.364505330811      =      0.0001348722346941
# 4       70.2827512985586      =       193.3866025490196
# 5      87.27527411438841      =      28.658721352941186
# 6      2.863086227324989      =   1.680172171764706e-05
# 7     103.54521195534517      =      122.19394274509804
# 8     143.15790074042718      =       29.67318862745098
# 9      5609.286755499401      =      0.0017554558823529
#
#                     p11.1  p11.2                     p12  \
# 0                     STD  +/-/=                       F
# 1   6.270967923870664e-08      -      29894.953529411763
# 2  1.0810463476281284e+18      +  2.3645876983016074e+45
# 3      0.0009302020935676      -       84329.10246274508
# 4      30.595504294470643      +       244.4692553137255
# 5        5.22418732501046      -       520.1383449215687
# 6   6.779526094824887e-06      -       40.42784945098038
# 7       4.422605028948294      -       738.4572124117645
# 8       7.402988417715064      -       582.3323075882354
# 9      0.0124129475848557      -       14829.47715490196
#
#                    p12.1  p12.2
# 0                    STD  +/-/=
# 1     10302.991724408595      =
# 2  4.525833470544033e+45      =
# 3      7564.002995909293      =
# 4      31.92449232317764      =
# 5      22.83229479231352      =
# 6      2.376515022252767      =
# 7      88.08970121203329      =
# 8     30.351333386528697      =
# 9      809.4191882523877      =
#
# [10 rows x 34 columns]

# %% [markdown]
# ## Counting superior performances

# %%
data_wilcoxon = pd.read_csv('formatted_wilcoxon_results_control_p10_13.csv')
print(data_wilcoxon.head())

results = {}
comparison_columns = [col for col in data_wilcoxon.columns if col.endswith('.2')]

for col in comparison_columns:
    paper = col.split('.')[0]
    results[paper] = 0

for index, row in data_wilcoxon.iterrows():
    for col in comparison_columns:
        paper = col.split('.')[0]
        symbol = row[col]
        if symbol == '-':
            results[paper] += 1

print("Number of times each paper was better than the control (p10):")
for paper, count in results.items():
    print(f"{paper}: {count}")
# Out:
#   Unnamed: 0                      p1                    p1.1   p1.2  \
# 0        NaN                       F                     STD  +/-/=
# 1         f1  2.2701176470588234e-10  1.6052155823265436e-09      -
# 2         f2       53097.16878693419      246760.10374764717      +
# 3         f3      0.0001773273333333        0.00018813044377      -
# 4         f4       192.9354411764706      20.213162505093656      +
#
#                        p2                   p2.1   p2.2                  p3  \
# 0                       F                    STD  +/-/=                   F
# 1                     0.0                    0.0      -   32.57554795098039
# 2  1.7553715518650285e+17  8.800764299140166e+17      +  11599.679019607842
# 3      0.0001128210645686     0.0007727962943159      -    367.391294117647
# 4       162.6124771352941      81.17668489951109      +   262412.8274509804
#
#                 p3.1   p3.2  ...   p9.2                 p10  \
# 0                STD  +/-/=  ...  +/-/=                   F
# 1  34.87542012384564      =  ...      +  12173.633333333337
# 2  886.8786449827788      =  ...      +  0.0001361798039215
# 3  43.45846034254858      =  ...      +   3941.176470588235
# 4  112478.9953176271      =  ...      +   90.73994705882356
#
#                    p10.1  p10.2                     p11  \
# 0                    STD  +/-/=                       F
# 1     13016.732617487516      =   6.593327656862745e-08
# 2  7.077482161384343e-05      =  1.6474331350583392e+17
# 3      1719.364505330811      =      0.0001348722346941
# 4       70.2827512985586      =       193.3866025490196
#
#                     p11.1  p11.2                     p12  \
# 0                     STD  +/-/=                       F
# 1   6.270967923870664e-08      -      29894.953529411763
# 2  1.0810463476281284e+18      +  2.3645876983016074e+45
# 3      0.0009302020935676      -       84329.10246274508
# 4      30.595504294470643      +       244.4692553137255
#
#                    p12.1  p12.2
# 0                    STD  +/-/=
# 1     10302.991724408595      =
# 2  4.525833470544033e+45      =
# 3      7564.002995909293      =
# 4      31.92449232317764      =
#
# [5 rows x 34 columns]
# Number of times each paper was better than the control (p10):
# p1: 25
# p2: 27
# p3: 0
# p4: 26
# p5: 27
# p7: 28
# p8: 0
# p9: 6
# p10: 0
# p11: 28
# p12: 0

# %% [markdown]
# ## Wilcoxon Summary

# %%
import pandas as pd
from scipy.stats import wilcoxon

data = pd.read_csv('Dim 100_13.csv')

control = 'p10'
algorithms = [col for col in data.columns[1:13] if col != control]

results_list = []

for alg in algorithms:
    data_control = data[control].dropna().astype(float)
    data_alg = data[alg].dropna().astype(float)
    
    if len(data_control) > 0 and len(data_alg) > 0:
        stat, p_value = wilcoxon(data_control, data_alg, alternative='two-sided')
        better_count = sum(data_alg > data_control)
        worse_count = sum(data_alg < data_control)
        equal_count = sum(data_alg == data_control)
        
        l_value = '+' if better_count > worse_count else '-' if worse_count > better_count else '='
        
        results_list.append({
            'Proposed algorithm': alg,
            'R+': better_count,
            'R-': worse_count,
            'R=': equal_count,
            'P-value': f"{p_value:.2E}" if p_value is not None else "N/A",
            'L-value': l_value
        })

results = pd.DataFrame(results_list)


results.to_csv('wilcoxon_summary_results_control_p10_13.csv', index=False)

results
# Out:
#   Proposed algorithm  R+  R-  R=   P-value L-value
# 0                 p1   5  25   0  6.08E-04       -
# 1                 p2   3  27   0  7.99E-06       -
# 2                 p3  11  19   0  2.53E-01       -
# 3                 p4   4  26   0  5.59E-05       -
# 4                 p5   3  27   0  6.92E-06       -
# 5                 p7   2  28   0  2.76E-06       -
# 6                 p8  16  14   0  1.40E-01       +
# 7                 p9  24   6   0  2.83E-04       +
# 8                p11   2  28   0  6.92E-06       -
# 9                p12  19  11   0  1.52E-01       +

# %% [markdown]
# # Dim 100_14

# %%
import pandas as pd
from scipy.stats import wilcoxon

means = pd.read_csv('Dim 100_14.csv', index_col=0)
stds = pd.read_csv('Dim 100_std_14.csv', index_col=0)

functions = means.index.tolist()
papers = means.columns.tolist()

reference_paper = 'p10'

if reference_paper not in papers:
    papers.append(reference_paper)

formatted_results = pd.DataFrame(index=functions, columns=pd.MultiIndex.from_product([papers, ['F', 'STD', '+/-/=']]))

for function in functions:
    formatted_results.loc[function, (reference_paper, 'F')] = means.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, 'STD')] = stds.loc[function, reference_paper]
    formatted_results.loc[function, (reference_paper, '+/-/=')] = '='  # Indicate no comparison

for paper in papers:
    if paper == reference_paper:
        continue  # Skip comparison logic for p10
    for function in functions:
        data_ref = means.loc[function, reference_paper]
        data_comp = means.loc[function, paper]
        std_ref = stds.loc[function, reference_paper]
        std_comp = stds.loc[function, paper]

        try:
            stat, p_value = wilcoxon(means.loc[:, reference_paper].dropna(), means.loc[:, paper].dropna(), alternative='two-sided')
            if p_value <= 0.05:
                symbol = '-' if data_ref > data_comp else '+'
            else:
                symbol = '='
        except Exception as e:
            symbol = 'Err'
            print(f"Error: {e}")

        formatted_results.loc[function, (paper, 'F')] = data_comp
        formatted_results.loc[function, (paper, 'STD')] = std_comp
        formatted_results.loc[function, (paper, '+/-/=')] = symbol

formatted_results.to_csv('formatted_wilcoxon_results_control_p10_14.csv')
print(formatted_results.head())
# Out:
#             p1                                p2                          \
#              F        STD +/-/=                F               STD +/-/=
# f1         0.0        0.0     -              0.0               0.0     -
# f2    8.940308  23.963477     +  53191785.431373  365191655.903715     +
# f3    0.000002   0.000003     -         0.000001           0.00001     -
# f4  189.632271   28.63809     +       162.612477         81.176685     +
# f5   43.907776   5.551345     -        35.436256         13.031623     -
#
#               p3                               p4  ...    p9          p10  \
#                F            STD +/-/=           F  ... +/-/=            F
# f1      4.014401        4.91638     =         0.0  ...     +  12158.47451
# f2  11599.524118     886.912429     =         0.0  ...     +     0.000118
# f3    223.631176      44.832565     =         0.0  ...     +  1842.313725
# f4  233930.45098  101303.149381     =  155.986832  ...     +    78.914037
# f5   2525.710137    2118.363949     =   11.001261  ...     -   623.509804
#
#                                         p11                              \
#              STD +/-/=                    F                   STD +/-/=
# f1  13003.494234     =                  0.0                   0.0     -
# f2      0.000067     =  75837540315140784.0  503156521945966016.0     +
# f3    909.058239     =                  0.0              0.000001     -
# f4     71.179009     =           193.386603             30.595504     +
# f5     87.805349     =            28.658721              5.224187     -
#
#                                                 p12  \
#                                                   F
# f1                                     10765.040685
# f2  221514584620889779013586719852703040952860672.0
# f3                                     72471.719765
# f4                                       240.212825
# f5                                       520.129678
#
#
#                                                 STD +/-/=
# f1                                      3273.193477     =
# f2  334390468623806186170397962532565919211716608.0     =
# f3                                      6533.401012     =
# f4                                        30.892704     =
# f5                                        22.833831     =
#
# [5 rows x 33 columns]

# %%
wilcoxon_results = pd.read_csv('formatted_wilcoxon_results_control_p10_14.csv')

wilcoxon_results.head(10)
# Out:
#   Unnamed: 0                     p1                    p1.1   p1.2  \
# 0        NaN                      F                     STD  +/-/=
# 1         f1                    0.0                     0.0      -
# 2         f2       8.94030762038179      23.963477213169824      +
# 3         f3  2.391170296078431e-06  2.6981504465163643e-06      -
# 4         f4      189.6322705882353      28.638089665060352      +
# 5         f5      43.90777647058824       5.551345400877028      -
# 6         f6     0.0002024403052941      0.0006137742850271      -
# 7         f7      144.8983333333333       6.636940036323338      -
# 8         f8     42.152486274509805       5.467874184368742      -
# 9         f9     0.0459039568627451      0.1137956282776918      -
#
#                        p2                   p2.1   p2.2                  p3  \
# 0                       F                    STD  +/-/=                   F
# 1                     0.0                    0.0      -   4.014400574313726
# 2       53191785.43137255      365191655.9037151      +   11599.52411764706
# 3  1.3718085630392157e-06  9.689627260043904e-06      -  223.63117647058823
# 4       162.6124771352941      81.17668489951109      +  233930.45098039217
# 5       35.43625607843137      13.03162347194542      -   2525.710137254902
# 6      0.0021885084798552     0.0025497128278487      -  1094.2222941176472
# 7      122.32349156862746      5.678112909095135      -   487.3394274509804
# 8       34.29564721568628      10.95678817821178      -  2070.8205882352945
# 9      0.8059393317647059      0.521407288842001      -   1620.973960784314
#
#                  p3.1   p3.2  ...   p9.2                 p10  \
# 0                 STD  +/-/=  ...  +/-/=                   F
# 1   4.916379956983023      =  ...      +   12158.47450980392
# 2   886.9124287743505      =  ...      +  0.0001181464705882
# 3   44.83256535228491      =  ...      +   1842.313725490196
# 4  101303.14938081594      =  ...      +   78.91403725490196
# 5   2118.363948634214      =  ...      -   623.5098039215686
# 6  1129.4743230391894      =  ...      +   9.442156862745096
# 7   484.5344255656509      =  ...      +   713.8235294117648
# 8    323.995397022567      =  ...      -   608.7647058823529
# 9  240.44138581660647      =  ...      +   5174.058823529412
#
#                    p10.1  p10.2                     p11  \
# 0                    STD  +/-/=                       F
# 1     13003.494234346535      =  1.3286578039215683e-09
# 2  6.698779941075981e-05      =   7.583754031514078e+16
# 3      909.0582390410824      =  2.9909385472549025e-07
# 4      71.17900919707742      =       193.3866025490196
# 5      87.80534901501063      =      28.658721352941186
# 6     2.7228433190508707      =  1.6288878088235296e-05
# 7     104.05988205936964      =      122.19394274509804
# 8     142.67962029821535      =       29.67318862745098
# 9      5577.741237298955      =      0.0017554558823529
#
#                     p11.1  p11.2                     p12  \
# 0                     STD  +/-/=                       F
# 1  7.4442742757775064e-09      -      10765.040684509804
# 2    5.03156521945966e+17      +  2.2151458462088978e+44
# 3   6.972728886254135e-07      -       72471.71976470588
# 4      30.595504294470643      +      240.21282494117648
# 5        5.22418732501046      -       520.1296784117648
# 6   7.062713371785916e-06      -       40.07777656862745
# 7       4.422605028948294      -        738.411911745098
# 8       7.402988417715064      -       582.3239852549018
# 9      0.0124129475848557      -      14775.633784313724
#
#                    p12.1  p12.2
# 0                    STD  +/-/=
# 1       3273.19347676921      =
# 2  3.343904686238062e+44      =
# 3      6533.401011549234      =
# 4      30.89270408590848      =
# 5     22.833830828683645      =
# 6      2.319053980542026      =
# 7      88.08948931918343      =
# 8      30.35050948380398      =
# 9      803.7488514723248      =
#
# [10 rows x 34 columns]

# %% [markdown]
# ## Counting superior performances

# %%
data_wilcoxon = pd.read_csv('formatted_wilcoxon_results_control_p10_14.csv')
print(data_wilcoxon.head())

results = {}
comparison_columns = [col for col in data_wilcoxon.columns if col.endswith('.2')]

for col in comparison_columns:
    paper = col.split('.')[0]
    results[paper] = 0

for index, row in data_wilcoxon.iterrows():
    for col in comparison_columns:
        paper = col.split('.')[0]
        symbol = row[col]
        if symbol == '-':
            results[paper] += 1

print("Number of times each paper was better than the control (p10):")
for paper, count in results.items():
    print(f"{paper}: {count}")
# Out:
#   Unnamed: 0                     p1                    p1.1   p1.2  \
# 0        NaN                      F                     STD  +/-/=
# 1         f1                    0.0                     0.0      -
# 2         f2       8.94030762038179      23.963477213169824      +
# 3         f3  2.391170296078431e-06  2.6981504465163643e-06      -
# 4         f4      189.6322705882353      28.638089665060352      +
#
#                        p2                   p2.1   p2.2                  p3  \
# 0                       F                    STD  +/-/=                   F
# 1                     0.0                    0.0      -   4.014400574313726
# 2       53191785.43137255      365191655.9037151      +   11599.52411764706
# 3  1.3718085630392157e-06  9.689627260043904e-06      -  223.63117647058823
# 4       162.6124771352941      81.17668489951109      +  233930.45098039217
#
#                  p3.1   p3.2  ...   p9.2                 p10  \
# 0                 STD  +/-/=  ...  +/-/=                   F
# 1   4.916379956983023      =  ...      +   12158.47450980392
# 2   886.9124287743505      =  ...      +  0.0001181464705882
# 3   44.83256535228491      =  ...      +   1842.313725490196
# 4  101303.14938081594      =  ...      +   78.91403725490196
#
#                    p10.1  p10.2                     p11  \
# 0                    STD  +/-/=                       F
# 1     13003.494234346535      =  1.3286578039215683e-09
# 2  6.698779941075981e-05      =   7.583754031514078e+16
# 3      909.0582390410824      =  2.9909385472549025e-07
# 4      71.17900919707742      =       193.3866025490196
#
#                     p11.1  p11.2                     p12  \
# 0                     STD  +/-/=                       F
# 1  7.4442742757775064e-09      -      10765.040684509804
# 2    5.03156521945966e+17      +  2.2151458462088978e+44
# 3   6.972728886254135e-07      -       72471.71976470588
# 4      30.595504294470643      +      240.21282494117648
#
#                    p12.1  p12.2
# 0                    STD  +/-/=
# 1       3273.19347676921      =
# 2  3.343904686238062e+44      =
# 3      6533.401011549234      =
# 4      30.89270408590848      =
#
# [5 rows x 34 columns]
# Number of times each paper was better than the control (p10):
# p1: 27
# p2: 27
# p3: 0
# p4: 26
# p5: 27
# p7: 28
# p8: 0
# p9: 6
# p10: 0
# p11: 27
# p12: 0

# %% [markdown]
# ## Wilcoxon Summary

# %%
import pandas as pd
from scipy.stats import wilcoxon

data = pd.read_csv('Dim 100_14.csv')

control = 'p10'
algorithms = [col for col in data.columns[1:13] if col != control]

results_list = []

for alg in algorithms:
    data_control = data[control].dropna().astype(float)
    data_alg = data[alg].dropna().astype(float)
    
    if len(data_control) > 0 and len(data_alg) > 0:
        stat, p_value = wilcoxon(data_control, data_alg, alternative='two-sided')
        better_count = sum(data_alg > data_control)
        worse_count = sum(data_alg < data_control)
        equal_count = sum(data_alg == data_control)
        
        l_value = '+' if better_count > worse_count else '-' if worse_count > better_count else '='
        
        results_list.append({
            'Proposed algorithm': alg,
            'R+': better_count,
            'R-': worse_count,
            'R=': equal_count,
            'P-value': f"{p_value:.2E}" if p_value is not None else "N/A",
            'L-value': l_value
        })

results = pd.DataFrame(results_list)


results.to_csv('wilcoxon_summary_results_control_p10_14.csv', index=False)

results
# Out:
#   Proposed algorithm  R+  R-  R=   P-value L-value
# 0                 p1   3  27   0  6.15E-08       -
# 1                 p2   3  27   0  9.22E-06       -
# 2                 p3  11  19   0  2.62E-01       -
# 3                 p4   4  26   0  4.41E-05       -
# 4                 p5   3  27   0  6.92E-06       -
# 5                 p7   2  28   0  4.66E-08       -
# 6                 p8  16  14   0  1.35E-01       +
# 7                 p9  24   6   0  3.13E-04       +
# 8                p11   3  27   0  7.99E-06       -
# 9                p12  17  13   0  4.04E-01       +
